# %% [markdown]
# <a href="https://colab.research.google.com/github/mylibui/demo/blob/master/AE_VAE_Modelle_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import datetime
from sklearn.decomposition import PCA
import seaborn as sns
import numpy as np
import os
import pandas as pd
from typing import Union, Tuple, Optional, List, Any,Dict

# %% [markdown]
# ## Datenaufbereiten

# %%
from google.colab import drive
drive.mount('/content/drive')
file_path= '/content/drive/MyDrive/Data/creditcard.csv'
df = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard

# %%
# Separate features and labels
X = df.drop(['Class'], axis=1).values
y = df['Class'].values

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# Only use normal transactions for training (Class = 0)
X_train_normal = X_train[y_train == 0]

# %%
X_train_normal.shape
#X_train.shape
# Out:
# (227451, 30)

# %%
X_train.shape
# Out:
# (227845, 30)

# %%
# Hyperparameters
input_dim = X_train.shape[1]
epoch=100
learning_rate=0.001
latent_dim=16
hidden_dims=[64,32]
dropout_rate=0.1
activation='mish'
batch_size=256
kl_weight=1
classifier_dim=[16,8]
callbacks=callbacks = [
    EarlyStopping(monitor='val_total_loss', patience=10, restore_best_weights=True,mode="min"),
    ReduceLROnPlateau(monitor='val_total_loss', factor=0.5, patience=5, min_lr=1e-6)

]

# %% [markdown]
# #0. Hilffunktion definiern

# %% [markdown]
# ## 1.Plot Verlustkurve

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from typing import Union, Optional, Tuple, List, Dict

def plot_loss_curves(
    history: Union[tf.keras.callbacks.History, Dict],
    model_type: str,
    figsize: Tuple[int, int] = (20, 8),
    save_path: Optional[str] = None,
    folder_name: str = "vae_results/loss_curves"
) -> Tuple[plt.Figure, List[plt.Axes]]:
    """
    Plottet umfassende Loss-Kurven für verschiedene Autoencoder-Modelltypen (UnsupervisedAE, UnsupervisedVAE,
    SupervisedAE, SupervisedVAE) und speichert sie optional in einem Google Drive-Ordner.

    Args:
        history: Das History-Objekt aus dem `model.fit()`-Aufruf oder ein Dictionary mit Metriken.
        model_type: Typ des Modells ('uae', 'uvae', 'sae', 'svae'). Standardwert ist 'uae'.
        figsize: Größe der Abbildung als Tuple (Breite, Höhe). Standardwert ist (16, 10).
        save_path: Optionaler Pfad, um das Plot zu speichern (Standardwert ist None). Wenn None, wird der Pfad aus folder_name generiert.
        folder_name: Name des Ordners (relativ zu /content/drive/MyDrive/), in dem das Plot gespeichert werden soll (Standardwert ist "vae_results/loss_curves").

    Returns:
        Tuple[plt.Figure, List[plt.Axes]]: Figure- und Axes-Objekte für weitere Anpassungen.

    Raises:
        ValueError: Wenn `history` kein gültiges History-Objekt oder Dictionary ist, `model_type` unbekannt ist, oder keine gültigen Metriken vorhanden sind.
        TypeError: Wenn `figsize` kein Tuple oder `history` kein Dict/History-Objekt ist.
    """

    # Extrahiere Metriken aus History oder Dictionary
    metrics = list(history.history.keys() if isinstance(history, tf.keras.callbacks.History) else history.keys())
    if not metrics:
        raise ValueError("Keine Metriken in history vorhanden")

    # Bestimme relevante Loss-Metriken basierend auf dem Modelltyp
    loss_metrics = [m for m in metrics if 'loss' in m.lower() and 'val' not in m]
    val_metrics_exist = any('val_' in m for m in metrics)

    # Konfiguriere die Anzahl der Subplots basierend auf dem Modelltyp
    if model_type in ['uae', 'uvae']:
        expected_losses = ['total_loss', 'reconstruction_loss']
        if model_type == 'uvae':
            expected_losses.append('kl_loss')
        n_plots = min(3, len([m for m in loss_metrics if m in expected_losses]))
    else:  # 'sae', 'svae'
        expected_losses = ['total_loss', 'reconstruction_loss', 'classification_loss']
        if model_type == 'svae':
            expected_losses.append('kl_loss')
        n_plots = min(4, len([m for m in loss_metrics if m in expected_losses]))

    # Erstelle Figure und Axes
    fig, axes = plt.subplots(1, n_plots, figsize=figsize)
    if n_plots == 1:
        axes = [axes]  # Für Konsistenz bei einem einzigen Plot

    # Farben und Stil für die Plots
    colors = {
        'total_loss': 'blue',
        'reconstruction_loss': 'green',
        'kl_loss': 'cyan',
        'classification_loss': 'orange'
    }
    line_styles = {'training': '-', 'validation': '--'}

    # Plot-Index
    ax_idx = 0

    # Plot 1: Gesamtverlust (falls vorhanden, ansonsten überspringen)
    if 'total_loss' in metrics:
        ax = axes[ax_idx]
        ax.plot(history.history['total_loss'], color=colors['total_loss'], linestyle=line_styles['training'],
                linewidth=2, label='Training')
        if val_metrics_exist and 'val_total_loss' in metrics:
            # FIX: Use the same color for validation as for training
            ax.plot(history.history['val_total_loss'], color=colors['total_loss'], linestyle=line_styles['validation'],
                    linewidth=2, label='Validierung')

        ax.set_title('Gesamtverlust', fontsize=14)
        ax.set_xlabel('Epoch', fontsize=12)
        ax.set_ylabel('Loss', fontsize=12)
        ax.legend(loc='best', fontsize=10)
        ax.grid(alpha=0.3)

        # Annotations für Start- und Endwerte
        start_val = history.history['total_loss'][0]  # FIX: Use first value instead of index 1
        end_val = history.history['total_loss'][-1]
        ax.annotate(f'Start: {start_val:.4f}', xy=(0, start_val), xytext=(5, 10),
                    textcoords='offset points', color=colors['total_loss'], fontsize=10)
        ax.annotate(f'End: {end_val:.4f}', xy=(len(history.history['total_loss'])-1, end_val),
                   xytext=(5, -15), textcoords='offset points', color=colors['total_loss'], fontsize=10)

        if val_metrics_exist and 'val_total_loss' in metrics:
            val_start = history.history['val_total_loss'][0]
            val_end = history.history['val_total_loss'][-1]
            ax.annotate(f'Start: {val_start:.4f}', xy=(0, val_start), xytext=(5, -30),
                        textcoords='offset points', color=colors['total_loss'], fontsize=10)  # FIX: Use total_loss color
            ax.annotate(f'End: {val_end:.4f}', xy=(len(history.history['val_total_loss'])-1, val_end),
                       xytext=(5, -45), textcoords='offset points', color=colors['total_loss'], fontsize=10)  # FIX: Use total_loss color

        ax_idx += 1
    else:
        print("Warnung: 'loss' nicht in history.history gefunden – Gesamtverlust wird nicht geplottet.")

    # Plot 2: Rekonstruktionsverlust
    if 'reconstruction_loss' in metrics and ax_idx < n_plots:
        ax = axes[ax_idx]
        ax.plot(history.history['reconstruction_loss'], color=colors['reconstruction_loss'], linestyle=line_styles['training'],
                linewidth=2, label='Training')
        if val_metrics_exist and 'val_reconstruction_loss' in metrics:
            ax.plot(history.history['val_reconstruction_loss'], color=colors['reconstruction_loss'], linestyle=line_styles['validation'],
                    linewidth=2, label='Validierung')

        ax.set_title('Rekonstruktionsverlust', fontsize=14)
        ax.set_xlabel('Epoch', fontsize=12)
        ax.set_ylabel('Loss', fontsize=12)
        ax.legend(loc='best', fontsize=10)
        ax.grid(alpha=0.3)

        # Annotations für Endwerte
        end_val = history.history['reconstruction_loss'][-1]
        ax.annotate(f'End: {end_val:.4f}', xy=(len(history.history['reconstruction_loss'])-1, end_val),
                   xytext=(5, 10), textcoords='offset points', color=colors['reconstruction_loss'], fontsize=10)

        if val_metrics_exist and 'val_reconstruction_loss' in metrics:
            val_end = history.history['val_reconstruction_loss'][-1]
            ax.annotate(f'End: {val_end:.4f}', xy=(len(history.history['reconstruction_loss'])-1, val_end),
                       xytext=(5, -15), textcoords='offset points', color=colors['reconstruction_loss'], fontsize=10)

        ax_idx += 1

    # Plot 3: KL-Divergenz (nur für UnsupervisedVAE und SupervisedVAE)
    if 'kl_loss' in metrics and ax_idx < n_plots and model_type in ['uvae', 'svae']:
        ax = axes[ax_idx]
        ax.plot(history.history['kl_loss'], color=colors['kl_loss'], linestyle=line_styles['training'],
                linewidth=2, label='Training')
        if val_metrics_exist and 'val_kl_loss' in metrics:
            ax.plot(history.history['val_kl_loss'], color=colors['kl_loss'], linestyle=line_styles['validation'],
                    linewidth=2, label='Validierung')

        ax.set_title('KL-Divergenz', fontsize=14)
        ax.set_xlabel('Epoch', fontsize=12)
        ax.set_ylabel('Loss', fontsize=12)
        ax.legend(loc='best', fontsize=10)
        ax.grid(alpha=0.3)

        # Annotations für Endwerte
        end_val = history.history['kl_loss'][-1]
        ax.annotate(f'End: {end_val:.4f}', xy=(len(history.history['kl_loss'])-1, end_val),
                   xytext=(5, 10), textcoords='offset points', color=colors['kl_loss'], fontsize=10)

        if val_metrics_exist and 'val_kl_loss' in metrics:
            val_end = history.history['val_kl_loss'][-1]
            ax.annotate(f'End: {val_end:.4f}', xy=(len(history.history['kl_loss'])-1, val_end),
                       xytext=(5, -15), textcoords='offset points', color=colors['kl_loss'], fontsize=10)

        ax_idx += 1

    # Plot 4: Klassifikationsverlust (nur für SupervisedAE und SupervisedVAE)
    if 'classification_loss' in metrics and ax_idx < n_plots and model_type in ['sae', 'svae']:
        ax = axes[ax_idx]
        ax.plot(history.history['classification_loss'], color=colors['classification_loss'], linestyle=line_styles['training'],
                linewidth=2, label='Training')
        if val_metrics_exist and 'val_classification_loss' in metrics:
            ax.plot(history.history['val_classification_loss'], color=colors['classification_loss'], linestyle=line_styles['validation'],
                    linewidth=2, label='Validierung')

        ax.set_title('Klassifikationsverlust', fontsize=14)
        ax.set_xlabel('Epoch', fontsize=12)
        ax.set_ylabel('Loss', fontsize=12)
        ax.legend(loc='best', fontsize=10)
        ax.grid(alpha=0.3)

        # Annotations für Endwerte
        end_val = history.history['classification_loss'][-1]
        ax.annotate(f'End: {end_val:.4f}', xy=(len(history.history['classification_loss'])-1, end_val),
                   xytext=(5, 10), textcoords='offset points', color=colors['classification_loss'], fontsize=10)

        if val_metrics_exist and 'val_classification_loss' in metrics:
            val_end = history.history['val_classification_loss'][-1]
            ax.annotate(f'End: {val_end:.4f}', xy=(len(history.history['classification_loss'])-1, val_end),
                       xytext=(5, -15), textcoords='offset points', color=colors['classification_loss'], fontsize=10)

        ax_idx += 1

    # Gesamttitel
    plt.suptitle(f'Trainingsverlauf - {model_type.upper()} Modell', fontsize=16)
    plt.tight_layout()
    plt.subplots_adjust(top=0.9)  # Platz für den Suptitle

    # Speichern des Plots in einem Google Drive-Ordner
    if save_path is None:
        # Basisverzeichnis für Google Drive
        base_dir = "/content/drive/MyDrive"
        folder_path = os.path.join(base_dir, folder_name)

        # Erstelle den Ordner, falls er nicht existiert
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # Generiere einen eindeutigen Dateinamen basierend auf dem Modelltyp
        save_path = os.path.join(folder_path, f"loss_curves_{model_type}.png")

    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Loss-Kurven wurden gespeichert unter: {save_path}")
        #plt.close()  # Speicherfreigabe in Google Colab

    return fig, axes

# %% [markdown]
# ## 2.Rekonstruktiomfehler berechnen

# %%
def calculate_reconstruction_error(
    model: Union['UnsupervisedAE'
                 , 'UnsupervisedVAE'
                 , 'SupervisedAE'
                 , 'SupervisedVAE'
                 ],
    X: np.ndarray
) -> np.ndarray:
    """
    Berechnet den Rekonstruktionsfehler (MSE) für ein Modell.

    Args:
        model: Das Modell, für das der Rekonstruktionsfehler berechnet werden soll (UnsupervisedAE, UnsupervisedVAE, SupervisedAE, oder SupervisedVAE).
        X: Eingabedaten als NumPy-Array oder Tensor der Form (Batch-Größe, input_dim).

    Returns:
        np.ndarray: Array mit MSE-Werten pro Sample.

    Raises:
        ValueError: Wenn das Modell einen unbekannten Typ hat oder X ungültig ist.
        TypeError: Wenn X kein NumPy-Array oder Tensor ist.
    """
    # Rekonstruktion basierend auf Modelltyp
    if isinstance(model, UnsupervisedAE):
        reconstructed = model(X, training=False)  # Nur rekonstruierte Daten für UnsupervisedAE
    elif isinstance(model, UnsupervisedVAE):
        reconstructed, _, _ = model(X, training=False)  # Ignoriere z_mean und z_log_var, nehme nur rekonstruiert
    elif isinstance(model, SupervisedAE):
        reconstructed, _ = model(X, training=False)  # Ignoriere Klassifikationsausgabe
    elif isinstance(model, SupervisedVAE):
        reconstructed, _, _, _ = model(X, training=False)  # Ignoriere z_mean, z_log_var und Klassifikation

    # Berechnung des MSE pro Sample
    reconstruction_error = tf.reduce_mean(tf.square(X - reconstructed), axis=-1)

    # Konvertierung zu NumPy-Array für einfache Handhabung
    return reconstruction_error.numpy()

# %% [markdown]
# plot rekonstruktion fehler

# %% [markdown]
# ##3.Plot Rekonstruktion fehler hist & boxplot

# %%
import os
from typing import Union, Optional
def plot_reconstruction_analysis(
    model: Union['UnsupervisedAE'
                 , 'UnsupervisedVAE', 'SupervisedAE'
                 , 'SupervisedVAE'
                 ],
    X: np.ndarray,
    y: np.ndarray,
    threshold: Optional[float] = None,
    save_path: Optional[str] = None,
    folder_name: str = "vae_results/reconstruction_analysis"
) -> None:
    """
    Plottet einen Boxplot und die Verteilung (Histogramm mit Dichte) des Rekonstruktionsfehlers für Fraud und Nicht Fraud in einem Google Drive-Ordner.

    Args:
        model: Das Modell, für das der Rekonstruktionsfehler berechnet werden soll (UnsupervisedAE, UnsupervisedVAE, SupervisedAE, oder SupervisedVAE).
        X: Eingabedaten als NumPy-Array oder Tensor der Form (Batch-Größe, input_dim).
        y: Labels als NumPy-Array (0 für Nicht Fraud, 1 für Fraud).
        threshold: Optionaler Schwellenwert für Anomaliedetektion (Standardwert ist None, dann wird find_optimal_threshold verwendet).
        save_path: Optionaler Pfad, um das Plot zu speichern (Standardwert ist None). Wenn None, wird der Pfad aus folder_name generiert.
        folder_name: Name des Ordners (relativ zu /content/drive/MyDrive/), in dem das Plot gespeichert werden soll (Standardwert ist "vae_results/reconstruction_analysis").

    Raises:
        ValueError: Wenn das Modell einen unbekannten Typ hat, X oder y ungültig sind.
        TypeError: Wenn X oder y kein NumPy-Array oder Tensor ist.
    """
    # Berechne Rekonstruktionsfehler
    reconstruction_error = calculate_reconstruction_error(model, X)

    # Bestimme optimalen Schwellenwert, falls keiner angegeben ist
    if threshold is None:
        threshold, _ = find_optimal_threshold(model, X, y)
    # Trennen von Fraud und Nicht Fraud Daten
    not_fraud_error = reconstruction_error[y == 0]
    fraud_error = reconstruction_error[y == 1]

    # Kombinierte Daten für Boxplot und Histogramm
    data = np.concatenate([not_fraud_error, fraud_error])
    labels = np.concatenate([np.repeat('Nicht Fraud', len(not_fraud_error)), np.repeat('Fraud', len(fraud_error))])

    # Speichern des Plots in einem Google Drive-Ordner
    if save_path is None:
        # Basisverzeichnis für Google Drive
        base_dir = "/content/drive/MyDrive"
        folder_path = os.path.join(base_dir, folder_name)

        # Erstelle den Ordner, falls er nicht existiert
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # Generiere einen eindeutigen Dateinamen
        import datetime
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        save_path = os.path.join(folder_path, f"reconstruction_analysis_{timestamp}.png")

    # Erstellen des Plots
    plt.figure(figsize=(16, 6))

    # Boxplot (rechts)
    plt.subplot(1, 2, 2)
    sns.boxplot(x=labels, y=data, palette={'Nicht Fraud': 'blue', 'Fraud': 'red'})
    plt.title("Boxplot des Rekonstruktionsfehlers: Fraud vs. Nicht Fraud")
    plt.xlabel("")
    plt.ylabel("Rekonstruktionsfehler (MSE)")
    plt.axhline(y=threshold, color='black', linestyle='--', label=f' Schwellenwert = {threshold:.4f}')
    plt.legend()

    # Histogramm mit Dichte (links)
    plt.subplot(1, 2, 1)
    sns.histplot(data=not_fraud_error, bins=50, color='blue', label='Nicht Fraud', alpha=0.5, stat='density')
    sns.histplot(data=fraud_error, bins=50, color='red', label='Fraud', alpha=0.5, stat='density')

    plt.axvline(x=threshold, color='black', linestyle='--', label=f' Schwellenwert = {threshold:.4f}')
    plt.title("Verteilung des Rekonstruktionsfehlers (Dichte): Fraud vs. Nicht Fraud")
    plt.xlabel("Rekonstruktionsfehler (MSE)")
    plt.ylabel("Dichte")
    plt.legend()

    plt.tight_layout()

    # Speichern des Plots
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    #plt.close()  # Speicherfreigabe in Google Colab

    print(f"Analyse wurde gespeichert unter: {save_path}")

# %% [markdown]
# ## 4.Optimal Threshold finden

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import f1_score
from typing import Union, Optional
def find_optimal_threshold(
    model: Union['UnsupervisedAE'
                 , 'UnsupervisedVAE'
                 , 'SupervisedAE'
                 , 'SupervisedVAE'
                 ],
    X: np.ndarray,
    y: np.ndarray,
    quantile: float = 0.95
) -> Tuple[float, float]:
    """
    Berechnet den optimalen Schwellenwert basierend auf dem quantilen (z. B. 95%-Quantil) Rekonstruktionsfehler.

    Args:
        model: Das Modell (z. B. UnsupervisedAE, UnsupervisedVAE, SupervisedAE, SupervisedVAE),
               für das der Rekonstruktionsfehler berechnet wird.
        X: Eingabedaten als NumPy-Array (Form: (Batch-Größe, input_dim)).
        y: True-Labels als NumPy-Array (0 für Nicht Fraud, 1 für Fraud).
        quantile: Das Quantil, das als Schwellenwert genutzt wird (Standardwert ist 0.95).

    Returns:
        Tuple[float, float]: (Schwellenwert, F1-Score bei diesem Schwellenwert)
    """
    # Berechne den Rekonstruktionsfehler (vorausgesetzt, calculate_reconstruction_error ist definiert)
    reconstruction_error = calculate_reconstruction_error(model, X)

    # Bestimme den Schwellenwert als das quantile, z.B. 95%
    threshold = np.quantile(reconstruction_error, quantile)

    # Berechne die Vorhersagen basierend auf diesem Schwellenwert
    y_pred = (reconstruction_error > threshold).astype(int)

    # Berechne den F1-Score
    optimal_f1 = f1_score(y, y_pred)
    print(f"Optimaler Schwellenwert (quantile {quantile}): {threshold}")
    return threshold, optimal_f1

# %% [markdown]
# ## 5.Fraud Prediction definieren

# %%
def detect_fraud(
    model: Union['UnsupervisedAE'
                 , 'UnsupervisedVAE'
                 , 'SupervisedAE'
                 ,'SupervisedVAE'
                 ],
    X: np.ndarray,
    threshold: Optional[float] = None
) -> np.ndarray:
    """
    Detektiert Fraud-Transaktionen basierend auf dem Rekonstruktionsfehler und einem Schwellenwert.

    Args:
        model: Das Modell, für das der Rekonstruktionsfehler berechnet werden soll (UnsupervisedAE, UnsupervisedVAE, SupervisedAE, oder SupervisedVAE).
        X: Eingabedaten als NumPy-Array oder Tensor der Form (Batch-Größe, input_dim).
        threshold: Optionaler Schwellenwert für Anomaliedetektion (Standardwert ist None, dann wird find_optimal_threshold verwendet).

    Returns:
        np.ndarray: Array mit Vorhersagen (0 für Nicht Fraud, 1 für Fraud).

    Raises:
        ValueError: Wenn das Modell einen unbekannten Typ hat oder X ungültig ist.
        TypeError: Wenn X kein NumPy-Array oder Tensor ist.
    """

    # Berechne Rekonstruktionsfehler
    reconstruction_error = calculate_reconstruction_error(model, X)

    # Bestimme optimalen Schwellenwert, falls keiner angegeben ist
    if threshold is None:
        # Hier simulieren wir, dass wir Labels haben (z. B. aus Testdaten)
        # In der Praxis müssen Sie y_test bereitstellen
        # Für dieses Beispiel nehmen wir an, dass wir keine Labels haben und einen Standard-Schwellenwert verwenden
        threshold, _ = find_optimal_threshold(model, X, np.zeros(len(X)))  # Dummy-Labels für Demo
        print(f"Optimaler Schwellenwert (ohne echte Labels): {threshold}")

    # Detektiere Fraud basierend auf Schwellenwert
    fraud_predictions = (reconstruction_error > threshold).astype(int)

    return fraud_predictions

# %% [markdown]
# ## 6.Evaluate Fraud Detection definieren

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, accuracy_score, roc_auc_score
from typing import Union, Optional,Dict

def evaluate_fraud_detection(
    model: Union['UnsupervisedAE'
                 ,'UnsupervisedVAE'
                 , 'SupervisedAE'
                 , 'SupervisedVAE'
                 ],
    X: np.ndarray,
    y: np.ndarray,
    threshold: Optional[float],
    save_metrics: bool = False,
    folder_name: str = "vae_results/metrics"
) -> Dict[str, float]:
    """
    Evaluert die Fraud-Detektion, berechnet Metriken und gibt einen Klassifikationsbericht aus.

    Args:
        model: Das Modell, für das der Rekonstruktionsfehler berechnet werden soll (UnsupervisedAE, UnsupervisedVAE, SupervisedAE, oder SupervisedVAE).
        X: Eingabedaten als NumPy-Array oder Tensor der Form (Batch-Größe, input_dim).
        y: Labels als NumPy-Array (0 für Nicht Fraud, 1 für Fraud).
        threshold: Optionaler Schwellenwert für Anomaliedetektion (Standardwert ist None, dann wird find_optimal_threshold verwendet).
        save_metrics: Boolean, ob die Metriken in einer Textdatei in Google Drive gespeichert werden sollen (Standardwert ist False).
        folder_name: Name des Ordners (relativ zu /content/drive/MyDrive/), in dem die Metriken gespeichert werden sollen (Standardwert ist "vae_results/metrics").

    Returns:
        Dict[str, float]: Dictionary mit Metriken (Precision, Recall, F1-Score, Accuracy, ROC-AUC).

    Raises:
        ValueError: Wenn das Modell einen unbekannten Typ hat, X oder y ungültig sind.
        TypeError: Wenn X oder y kein NumPy-Array oder Tensor ist.
    """
        # Bestimme optimalen Schwellenwert, falls keiner angegeben ist
    if threshold is None:
        threshold, _ = find_optimal_threshold(model, X, y)
        print(f"Optimaler Schwellenwert basierend auf F1-Score: {threshold}")

    # Detektiere Fraud als 0,1
    fraud_predictions = detect_fraud(model, X, threshold)

    # Berechne Metriken
    precision = precision_score(y, fraud_predictions)
    recall = recall_score(y, fraud_predictions)
    f1 = f1_score(y, fraud_predictions)
    accuracy = accuracy_score(y, fraud_predictions)

    # Berechne ROC-AUC (benötigt Wahrscheinlichkeiten, daher verwenden wir Rekonstruktionsfehler als Score)
    roc_auc = roc_auc_score(y,fraud_predictions)

    # Erstelle Klassifikationsbericht
    print("\nKlassifikationsbericht:")
    print(classification_report(y, fraud_predictions, target_names=['Nicht Fraud', 'Fraud']))

    # Gib Metriken aus
    metrics_dict = {
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "Accuracy": accuracy,
        "ROC-AUC": roc_auc
    }
    print("\nMetriken:")
    for metric, value in metrics_dict.items():
        print(f"{metric}: {value:.4f}")

    # Speichere Metriken in Google Drive, falls gewünscht
    if save_metrics:
        # Basisverzeichnis für Google Drive
        base_dir = "/content/drive/MyDrive"
        folder_path = os.path.join(base_dir, folder_name)

        # Erstelle den Ordner, falls er nicht existiert
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # Generiere einen eindeutigen Dateinamen
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        metrics_path = os.path.join(folder_path, f"metrics_{timestamp}.txt")

        with open(metrics_path, 'w') as f:
            f.write("Klassifikationsbericht:\n")
            f.write(classification_report(y, fraud_predictions, target_names=['Nicht Fraud', 'Fraud']))
            f.write("\nMetriken:\n")
            for metric, value in metrics_dict.items():
                f.write(f"{metric}: {value:.4f}\n")

        print(f"Metriken wurden gespeichert unter: {metrics_path}")

    return metrics_dict

# %% [markdown]
# ## 7.Plot ROC_AUC curve

# %%
def plot_roc_auc_curve(
    model: Union['UnsupervisedAE'
                 , 'UnsupervisedVAE', 'SupervisedAE'
                 , 'SupervisedVAE'
                 ],
    X: np.ndarray,
    y: np.ndarray,
    threshold: Optional[float] = None,
    save_path: Optional[str] = None,
    folder_name: str = "vae_results/roc_curves"
) -> None:
    """
    Plottet die ROC-AUC-Kurve für ein Modell und speichert das Plot optional in einem Google Drive-Ordner.

    Args:
        model: Das Modell, für das die ROC-Kurve berechnet werden soll (UnsupervisedAE, UnsupervisedVAE, SupervisedAE, oder SupervisedVAE).
        X: Eingabedaten als NumPy-Array oder Tensor der Form (Batch-Größe, input_dim).
        y: Labels als NumPy-Array (0 für Nicht Fraud, 1 für Fraud).
        threshold: Optionaler Schwellenwert für Anomaliedetektion (Standardwert ist None, dann wird find_optimal_threshold verwendet).
        save_path: Optionaler Pfad, um das Plot zu speichern (Standardwert ist None). Wenn None, wird der Pfad aus folder_name generiert.
        folder_name: Name des Ordners (relativ zu /content/drive/MyDrive/), in dem das Plot gespeichert werden soll (Standardwert ist "vae_results/roc_curves").

    Raises:
        ValueError: Wenn das Modell einen unbekannten Typ hat, X oder y ungültig sind.
        TypeError: Wenn X oder y kein NumPy-Array oder Tensor ist.
    """

    # Berechne Rekonstruktionsfehler
    reconstruction_error = calculate_reconstruction_error(model, X)

    # Bestimme optimalen Schwellenwert, falls keiner angegeben ist
    threshold, _ = find_optimal_threshold(model, X, y)
    print(f"Optimaler Schwellenwert basierend auf F1-Score: {threshold}")
    # Extrahiere den Modellnamen
    model_name = model.__class__.__name__  # z. B. "UnsupervisedAE"
    # Berechne ROC-Kurve und AUC
    fpr, tpr, thresholds_roc = roc_curve(y,reconstruction_error)  # Negieren, da niedrigere Rekonstruktionsfehler normal sind
    roc_auc = auc(fpr, tpr)

    # Speichern des Plots in einem Google Drive-Ordner
    if save_path is None:
        # Basisverzeichnis für Google Drive
        base_dir = "/content/drive/MyDrive"
        folder_path = os.path.join(base_dir, folder_name)

        # Erstelle den Ordner, falls er nicht existiert
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # Generiere einen eindeutigen Dateinamen
        import datetime
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        save_path = os.path.join(folder_path, f"{model_name}roc_curve_{timestamp}.png")

    # Erstellen des Plots
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'{model_name} ROC curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Zufallsprognose')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('ROC-Kurve für Fraud-Detektion')
    plt.legend(loc="lower right")

    # Speichern des Plots
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    #plt.close()  # Speicherfreigabe in Google Colab

    print(f"ROC-Kurve wurde gespeichert unter: {save_path}")
    print(f"ROC-AUC: {roc_auc:.4f}")

# %% [markdown]
# ## 8.Plot laten Space

# %%
def plot_latent_space(
    model: Union['UnsupervisedAE'
                 , 'UnsupervisedVAE', 'SupervisedAE'
                 , 'SupervisedVAE'
                 ],
    X: np.ndarray,
    y: np.ndarray,
    save_path: Optional[str] = None,
    folder_name: str = "vae_results/latent_space"
) -> None:
    """
    Plottet den latenten Raum eines SupervisedAE-Modells als 2D-Scatterplot und speichert das Plot als PNG in einem Google Drive-Ordner.

    Args:
        model: Das SupervisedAE-Modell, dessen latenter Raum visualisiert werden soll.
        X: Eingabedaten als NumPy-Array oder Tensor der Form (Batch-Größe, input_dim).
        y: Labels als NumPy-Array (0 für Nicht Fraud, 1 für Fraud).
        save_path: Optionaler Pfad, um das Plot zu speichern (Standardwert ist None). Wenn None, wird der Pfad aus folder_name generiert.
        folder_name: Name des Ordners (relativ zu /content/drive/MyDrive/), in dem das Plot gespeichert werden soll (Standardwert ist "vae_results/latent_space").

    Raises:
        ValueError: Wenn das Modell einen unbekannten Typ hat, X oder y ungültig sind.
        TypeError: Wenn X oder y kein NumPy-Array oder Tensor ist.
    """

    # Konvertiere X zu Tensor, falls es ein NumPy-Array ist
    x = tf.convert_to_tensor(X, dtype=tf.float32)

    # Extrahiere den latenten Raum mit der encode-Methode
    # The original line was trying to call .numpy() on a tuple, which is not possible.
    # Assuming your encode method returns a tuple where the first element is the latent representation,
    # we need to access that element.
# Extrahiere den latenten Raum basierend auf dem Modelltyp
    if isinstance(model, UnsupervisedAE):
        latent_representation = model.encode(x).numpy()  # Direkte latente Darstellung
    elif isinstance(model, UnsupervisedVAE):
        z_mean, _, _ = model.encode(x)  # Nimm z_mean als latente Darstellung
        latent_representation = z_mean.numpy()
    elif isinstance(model, SupervisedAE):
        latent_representation = model.encode(x).numpy()  # Direkte latente Darstellung
    elif isinstance(model, SupervisedVAE):
        z_mean, _, _ = model.encode(x)  # Nimm z_mean als latente Darstellung
        latent_representation = z_mean.numpy()
    else:
        raise ValueError("Unbekannter Modelltyp – sollte nicht auftreten aufgrund vorheriger Validierung")

    # Reduziere die Dimensionen auf 2, falls latent_dim > 2
    if latent_representation.shape[1] > 2:
        pca = PCA(n_components=2)
        latent_2d = pca.fit_transform(latent_representation)
    else:
        latent_2d = latent_representation  # Verwende direkt die ersten zwei Dimensionen, wenn latent_dim <= 2

    # Speichern des Plots in einem Google Drive-Ordner
    if save_path is None:
        # Basisverzeichnis für Google Drive
        base_dir = "/content/drive/MyDrive"
        folder_path = os.path.join(base_dir, folder_name)

        # Erstelle den Ordner, falls er nicht existiert
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

     # Generiere einen eindeutigen Dateinamen basierend auf dem Modelltyp
        model_name = model.__class__.__name__
        import datetime
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        save_path = os.path.join(folder_path, f"latent_space_{model_name}.png")

    # Erstellen des Plots
    plt.figure(figsize=(10, 6))
    scatter = plt.scatter(latent_2d[:, 0], latent_2d[:, 1], c=y, cmap='bwr', alpha=0.5)
    plt.colorbar(scatter, label='Klasse (0 = Nicht Fraud, 1 = Fraud)')
    plt.title(f"Latenter Raum des {model_name}-Modells")
    plt.xlabel("Latente Dimension 1")
    plt.ylabel("Latente Dimension 2")

    # Speichern des Plots
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    #plt.close()  # Speicherfreigabe in Google Colab

    print(f"Latenter Raum wurde gespeichert unter: {save_path}")

# %%
def plot_confusion_matrix(model,y_true: np.ndarray, y_pred: np.ndarray, labels: list = None, title: str = 'Confusion Matrix',folder_name: str = "vae_results"):
    """
    Berechnet und plottet die Konfusionsmatrix.

    Args:
        y_true: Wahre Labels als NumPy-Array.
        y_pred: Vorhergesagte Labels als NumPy-Array.
        labels: Optionale Liste von Klassenbezeichnungen (Standard: ['Nicht Fraud', 'Fraud']).
        title: Titel für den Plot.
    """
    # Berechne die Konfusionsmatrix
    cm = confusion_matrix(y_true, y_pred)

    # Standardlabels setzen, falls nicht angegeben
    if labels is None:
        labels = ['Nicht Fraud', 'Fraud']

    # Plotten mit seaborn heatmap
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.ylabel('Wahre Labels')
    plt.xlabel('Vorhergesagte Labels')
    plt.title(f"{title} {model}")
    plt.show()
    # Speichern des Plots in einem Google Drive-Ordner
    # Initialize save_path here
    save_path = None

    if save_path is None:
        # Basisverzeichnis für Google Drive
        base_dir = "/content/drive/MyDrive"
        folder_path = os.path.join(base_dir, folder_name)

        # Erstelle den Ordner, falls er nicht existiert
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
    save_path = os.path.join(folder_path, f"confusion_matrix_{model}.png")
    plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 9. Plot AUC-PR Curve

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
def plot_pr_curve(
    model,
    X: np.ndarray,
    y: np.ndarray,
    save_path: str = None,
    folder_name: str = "results/pr_curve"
) -> None:
    """
    Plottet die Precision-Recall-Kurve für ein Modell und berechnet den Average Precision Score.

    Args:
        model: Das Modell (z.B. UnsupervisedAE, UnsupervisedVAE, SupervisedAE, SupervisedVAE),
               welches den Rekonstruktionsfehler liefert.
        X: Eingabedaten als NumPy-Array (Form: (Batch-Größe, input_dim)).
        y: True-Labels als NumPy-Array (0 für Nicht Fraud, 1 für Fraud).
        save_path: Optionaler Pfad, um das Plot zu speichern.
        folder_name: Ordnername (relativ zu einem Basisverzeichnis, z.B. Google Drive), in dem das Plot gespeichert werden soll.

    Returns:
        None
    """
    # Berechne den Rekonstruktionsfehler (angenommen, calculate_reconstruction_error ist definiert)
    reconstruction_error = calculate_reconstruction_error(model, X)

    # Berechne Precision-Recall-Kurve
    precision, recall, _ = precision_recall_curve(y, reconstruction_error)

    # Berechne den Average Precision Score (AUC-PR)
    avg_precision = average_precision_score(y, reconstruction_error)

    # Erstellen des Plots
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, marker='.', label=f'PR-Kurve (AP = {avg_precision:.4f})')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall-Kurve {model.name}')
    plt.legend(loc='lower left')
    plt.grid(True)

    # Optional: Speichern des Plots
    if save_path is None:
        base_dir = "/content/drive/MyDrive"
        folder_path = os.path.join(base_dir, folder_name)
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        save_path = os.path.join(folder_path, f"pr_curve_{timestamp}.png")

    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"Precision-Recall-Kurve wurde gespeichert unter: {save_path}")
    plt.show()

# %% [markdown]
# ## 10.HyperParameter definieren

# %% [markdown]
# #I. Unsupervised Autoencoder (AE)
#
#
# ---

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## 1.Klasse AE definieren

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, metrics
from typing import List, Optional, Union, Tuple

@tf.keras.utils.register_keras_serializable()
class UnsupervisedAE(Model):
    """
    Unüberwachter Autoencoder für Anomalieerkennung mit anpassbarer latenter Dimension.

    Args:
        input_dim (int): Dimension der Eingabedaten.
        hidden_dims (List[int]): Liste der Dimensionen der versteckten Schichten im Encoder/Decoder (Standard: [64, 32]).
        latent_dim (int): Dimension des latenten Raums (anpassbar, Standard: 32).
        activation (str, optional): Aktivierungsfunktion ('relu', 'mish', 'swish'). Standardwert ist 'relu'.
        dropout_rate (float, optional): Dropout-Rate zwischen 0 und 1. Standardwert ist 0.0.
    """
    def __init__(
        self,
        input_dim: int,
        hidden_dims: List[int] = [64, 32],
        latent_dim: int = 16,
        activation: str = 'relu',
        dropout_rate: float = 0.0, **kwargs
    ):
        super(UnsupervisedAE, self).__init__(**kwargs)
        self.input_dim = input_dim
        self.hidden_dims = hidden_dims
        self.latent_dim = latent_dim
        self.activation = activation
        self.dropout_rate = dropout_rate

        self.latent_dim = latent_dim
        self.dropout_rate = dropout_rate

        # Encoder-Schichten mit optionalem Dropout
        self.encoder_layers = [
            layers.Dense(dim, activation=self.activation if callable(self.activation) else self.activation)
            for dim in hidden_dims
        ]
        if dropout_rate > 0:
            self.encoder_dropout = layers.Dropout(dropout_rate)

        # Latente Schicht im Encoder
        self.latent_layer = layers.Dense(latent_dim, activation=None)  # Keine Aktivierung für latenten Raum

        # Decoder-Schichten mit optionalem Dropout
        self.decoder_layers = [
            layers.Dense(dim, activation=self.activation if callable(self.activation) else self.activation)
            for dim in reversed(hidden_dims)
        ]
        if dropout_rate > 0:
            self.decoder_dropout = layers.Dropout(dropout_rate)

        self.decoder_output = layers.Dense(input_dim, activation='sigmoid')

        # Metriken
        self.reconstruction_loss_tracker = metrics.Mean(name="total_loss")

    @property
    def metrics(self) -> List[metrics.Metric]:
        """Gibt die Liste der Metriken zurück."""
        return [self.reconstruction_loss_tracker]

    def encode(self, x: tf.Tensor) -> tf.Tensor:
        """
        Kodierung der Eingabedaten in den latenten Raum.

        Args:
            x: Eingabetensor der Form (Batch-Größe, input_dim).

        Returns:
            Latenter Tensor der Form (Batch-Größe, latent_dim).
        """
        for layer in self.encoder_layers:
            x = layer(x)
            if self.dropout_rate > 0:
                x = self.encoder_dropout(x, training=True)
        return self.latent_layer(x)

    def decode(self, z: tf.Tensor) -> tf.Tensor:
        """
        Dekodierung der latenten Variablen in rekonstruierte Daten.

        Args:
            z: Latenter Tensor der Form (Batch-Größe, latent_dim).

        Returns:
            Rekonstruierter Tensor der Form (Batch-Größe, input_dim).
        """
        x = z
        for layer in self.decoder_layers:
            x = layer(x)
            if self.dropout_rate > 0 and layer != self.decoder_layers[-1]:  # Kein Dropout in der letzten Schicht
                x = self.decoder_dropout(x, training=True)
        return self.decoder_output(x)

    def call(self, inputs: tf.Tensor, training: bool = False) -> tf.Tensor:
        """
        Vorwärtspass durch den Autoencoder.

        Args:
            inputs: Eingabetensor der Form (Batch-Größe, input_dim).
            training: Boolean, der angibt, ob Trainings- oder Inferenzmodus vorliegt.

        Returns:
            Rekonstruierter Tensor der Form (Batch-Größe, input_dim).
        """
        encoded = self.encode(inputs)
        reconstructed = self.decode(encoded)
        return reconstructed

    def train_step(self, data: Union[tf.Tensor, Tuple[tf.Tensor, tf.Tensor]]) -> Dict[str, float]:
        """
        Trainings-Schritt für den Autoencoder mit MSE-Verlust.

        Args:
            data: Eingabetensor der Trainingsdaten oder Tuple (x, y) für TensorFlow 2.18.

        Returns:
            Dictionary mit Metrikwerten.
        """
        if isinstance(data, tuple):
            if len(data) == 2:
                x, _ = data  # Ignoriere y, da es unüberwacht ist
            else:
                x = data[0]
        else:
            x = data

        with tf.GradientTape() as tape:
            reconstruction = self.call(x, training=True)
            reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.square(x - reconstruction), axis=-1))

        grads = tape.gradient(reconstruction_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.reconstruction_loss_tracker.update_state(reconstruction_loss)

        return {"reconstruction_loss": self.reconstruction_loss_tracker.result()}

    def test_step(self, data: Union[tf.Tensor, Tuple[tf.Tensor, tf.Tensor]]) -> Dict[str, float]:
        """
        Test-Schritt für den Autoencoder mit MSE-Verlust.

        Args:
            data: Eingabetensor der Testdaten oder Tuple (x, y) für TensorFlow 2.18.

        Returns:
            Dictionary mit Metrikwerten.
        """
        if isinstance(data, tuple):
            if len(data) == 2:
                x, _ = data  # Ignoriere y, da es unüberwacht ist
            else:
                x = data[0]
        else:
            x = data

        reconstruction = self.call(x, training=False)
        reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.square(x - reconstruction), axis=-1))

        self.reconstruction_loss_tracker.update_state(reconstruction_loss)

        return {"reconstruction_loss": self.reconstruction_loss_tracker.result()}

    def print_summary(self):
        """
        Gibt eine Zusammenfassung der Modellarchitektur aus.

        Diese Methode verwendet die `summary()`-Methode von TensorFlow/Keras, um die Layer, Parameter und Ausgabetypen anzuzeigen.
        """
        self.summary()

    def build(self, input_shape: Tuple[int, int]) -> None:
        """
        Baut das Modell explizit mit der angegebenen Eingabeform.

        Args:
            input_shape: Tuple der Form (Batch-Größe, input_dim), wobei Batch-Größe optional ist.

        Raises:
            ValueError: Wenn input_shape kein gültiges Tuple ist.
        """
        if isinstance(input_shape, tuple) and len(input_shape) >= 1:
            input_dim = input_shape[-1]  # Nehme die letzte Dimension als input_dim
        else:
            raise ValueError("input_shape muss ein Tuple sein, z. B. (None, input_dim)")

        # Erstelle ein Dummy-Input-Tensor, um das Modell zu bauen
        dummy_input = tf.zeros((1, input_dim), dtype=tf.float32)
        self.call(dummy_input, training=False)  # Baut das Modell, indem es auf Dummy-Daten angewendet wird

    def get_config(self):
        config = super(UnsupervisedAE, self).get_config()
        config.update({
            "input_dim": self.input_dim,
            "hidden_dims": self.hidden_dims,
            "latent_dim": self.latent_dim,
            "activation": self.activation.__name__ if callable(self.activation) else self.activation,
            "dropout_rate": self.dropout_rate,
        })
        # Falls "build_config" hinzugefügt wurde, kannst du ihn hier optional entfernen oder zurückgeben.
        # config["build_config"] = {"input_shape": [None, self.input_dim]}
        return config

    @classmethod
    def from_config(cls, config):
        # Entferne unerwünschte Schlüssel, bevor der Konstruktor aufgerufen wird
        config.pop("build_config", None)
        return cls(**config)

# %% [markdown]
# ## 2.Trainiern AE

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

# %%
# Erstellen und Trainieren des Autoencoders mit anpassbaren Parametern
uae = UnsupervisedAE(
    input_dim=X_train_normal.shape[1],
    hidden_dims=[64, 32],  # Standardmäßig [64, 32], aber anpassbar
    latent_dim=16,  # Anpassbar
    activation='mish',  # Anpassbar
    dropout_rate=0.1  # Anpassbar
)
uae.build(input_shape=(None, X_train.shape[1]))
# Konfigurieren des Optimierers
uae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

# Training des Autoencoders
history = uae.fit(
    X_train_normal,
    epochs=100,
    batch_size=batch_size,
    validation_split=0.1,
    verbose=0,callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_total_loss` which is not available. Available metrics are: reconstruction_loss,val_reconstruction_loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_total_loss` which is not available. Available metrics are: reconstruction_loss,val_reconstruction_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)

# %%
# Modell speichern
save_dir = "/content/drive/MyDrive/models"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
uae.save(os.path.join(save_dir, "UAE.keras"))

# %%
wieder_geladenes_modell = tf.keras.models.load_model(
    os.path.join(save_dir, "UAE.keras"),
    custom_objects={'UnsupervisedAE': UnsupervisedAE}
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/serialization_lib.py:730: UserWarning: Model 'unsupervised_ae' had a build config, but the model cannot be built automatically in `build_from_config(config)`. You should implement `def build_from_config(self, config)`, and you might also want to implement the method  that generates the config at saving time, `def get_build_config(self)`. The method `build_from_config()` is meant to create the state of the model (i.e. its variables) upon deserialization.
#   instance.build_from_config(build_config)
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 26 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Ausgabe der Modellzusammenfassung
uae.print_summary()
# Out:
# Model: "unsupervised_ae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (1, 64)                     │           1,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (1, 32)                     │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (1, 16)                     │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (1, 32)                     │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (1, 64)                     │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (1, 30)                     │           1,950 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 27,596 (107.80 KB)
#  Trainable params: 9,198 (35.93 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 18,398 (71.87 KB)

# %%
fig, axes = plot_loss_curves(
    history,
    model_type='uae',
    folder_name="ae_results"
)
# Out:
# Warnung: 'loss' nicht in history.history gefunden – Gesamtverlust wird nicht geplottet.
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/ae_results/loss_curves_uae.png

# %% [markdown]
# ## 3.Rekonstruktionsfehler berechnen

# %%
beste_threshold,_ = find_optimal_threshold(uae, X_test, y_test)
print(f"Optimaler Schwellenwert: {beste_threshold}")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.4083186507225012
# Optimaler Schwellenwert: 1.4083186507225012

# %%
display(beste_threshold)
# Out:
# 1.4083186507225012

# %%
# Visualisierung und Speichern in Google Drive mit Markierung von Fraud vs. Nicht Fraud
plot_reconstruction_analysis(
    uae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="ae_results",
    threshold=beste_threshold  # Verwende den optimalen Schwellenwert
)
# Out:
# <ipython-input-13-198ed5571b77>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=labels, y=data, palette={'Nicht Fraud': 'blue', 'Fraud': 'red'})
# Analyse wurde gespeichert unter: /content/drive/MyDrive/ae_results/reconstruction_analysis_20250309_084544.png

# %%
# Evaluieren der Fraud-Detektion, Metriken ausgeben und speichern
metrics = evaluate_fraud_detection(
    uae,
    X_test,
    y_test,
    save_metrics=True,  # Speichert Metriken in Google Drive
    folder_name="ae_results",
    threshold=beste_threshold
)
# Out:
# Klassifikationsbericht:
#               precision    recall  f1-score   support
#
#  Nicht Fraud       1.00      0.95      0.97     56864
#        Fraud       0.03      0.88      0.06        98
#
#     accuracy                           0.95     56962
#    macro avg       0.51      0.91      0.52     56962
# weighted avg       1.00      0.95      0.97     56962
#
#
# Metriken:
# Precision: 0.0301
# Recall: 0.8776
# F1-Score: 0.0583
# Accuracy: 0.9512
# ROC-AUC: 0.9144
# Metriken wurden gespeichert unter: /content/drive/MyDrive/ae_results/metrics_20250309_084546.txt

# %%
fraud_predictions = detect_fraud(uae, X_test, beste_threshold
)
plot_confusion_matrix(model="Unsupervised AE", y_true=y_test, y_pred=fraud_predictions,folder_name="ae_results")

# %% [markdown]
# ## 4.Plot AUC ROC /AUC PR Kurve

# %%
plot_roc_auc_curve(
    uae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="ae_results")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.4135474562644947
# Optimaler Schwellenwert basierend auf F1-Score: 1.4135474562644947
# ROC-Kurve wurde gespeichert unter: /content/drive/MyDrive/ae_results/UnsupervisedAEroc_curve_20250309_084547.png
# ROC-AUC: 0.9555

# %%
plot_pr_curve(
    uae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="ae_results")
# Out:
# Precision-Recall-Kurve wurde gespeichert unter: /content/drive/MyDrive/ae_results/pr_curve_20250309_084547.png

# %%
plot_latent_space(
    uae,
    X_test,
    np.squeeze(y_test),
    folder_name="ae_results/latent_space"
)
# Out:
# Latenter Raum wurde gespeichert unter: /content/drive/MyDrive/ae_results/latent_space/latent_space_UnsupervisedAE.png

# %% [markdown]
# #II. Unsupervsied VAE
#
#
#
#
# ---

# %% [markdown]
# ## 1.VAE Klasse definieren

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, metrics
from typing import List, Optional, Union, Tuple
@tf.keras.utils.register_keras_serializable()

class UnsupervisedVAE(Model):
    """
    Unüberwachter Variational Autoencoder für Anomalieerkennung.

    Args:
        input_dim (int): Dimension der Eingabedaten.
        latent_dim (int): Dimension des latenten Raums (Standard: 16).
        hidden_dims (List[int]): Liste der Dimensionen der versteckten Schichten im Encoder/Decoder (Standard: [64, 32]).
        activation (str, optional): Aktivierungsfunktion ('relu', 'mish', 'swish'). Standardwert ist 'relu'.
        dropout_rate (float, optional): Dropout-Rate zwischen 0 und 1. Standardwert ist 0.0.
        kl_weight (float, optional): Gewichtungsfaktor für den KL-Verlust. Standardwert ist 1.0.
    """
    def __init__(
        self,
        input_dim: int,
        latent_dim: int = 16,
        hidden_dims: List[int] = [64, 32],
        activation: str = 'relu',
        dropout_rate: float = 0.0,
        kl_weight: float = 1.0,**kwargs
    ):
        super(UnsupervisedVAE, self).__init__(**kwargs)
        self.input_dim = input_dim
        self.hidden_dims = hidden_dims
        self.latent_dim = latent_dim
        self.activation = activation
        self.dropout_rate = dropout_rate

        self.latent_dim = latent_dim
        self.dropout_rate = dropout_rate
        self.kl_weight = kl_weight

        # Encoder-Schichten mit optionalem Dropout
        self.encoder_layers = [
            layers.Dense(dim, activation=self.activation if callable(self.activation) else self.activation)
            for dim in hidden_dims
        ]
        if dropout_rate > 0:
            self.encoder_dropout = layers.Dropout(dropout_rate)

        self.z_mean = layers.Dense(latent_dim)
        self.z_log_var = layers.Dense(latent_dim)

        class Sampling(layers.Layer):
            def call(self, inputs: Tuple[tf.Tensor, tf.Tensor]) -> tf.Tensor:
                z_mean, z_log_var = inputs
                batch = tf.shape(z_mean)[0]
                dim = tf.shape(z_mean)[1]
                epsilon = tf.random.normal(shape=(batch, dim))
                return z_mean + tf.exp(0.5 * z_log_var) * epsilon

        self.sampling = Sampling()

        # Decoder-Schichten mit optionalem Dropout
        self.decoder_layers = [
            layers.Dense(dim, activation=self.activation if callable(self.activation) else self.activation)
            for dim in reversed(hidden_dims)
        ]
        if dropout_rate > 0:
            self.decoder_dropout = layers.Dropout(dropout_rate)

        self.decoder_output = layers.Dense(input_dim, activation='linear')

        # Metriken
        self.total_loss_tracker = metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = metrics.Mean(name="kl_loss")

    @property
    def metrics(self) -> List[metrics.Metric]:
        """Gibt die Liste der Metriken zurück."""
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def encode(self, x: tf.Tensor) -> Tuple[tf.Tensor, tf.Tensor, tf.Tensor]:
        """
        Kodierung der Eingabedaten in den latenten Raum.

        Args:
            x: Eingabetensor der Form (Batch-Größe, input_dim).

        Returns:
            Tuple[tf.Tensor, tf.Tensor, tf.Tensor]: (z_mean, z_log_var, z) – Mittelwert, Log-Varianz und gestochastische latente Variable.
        """
        for layer in self.encoder_layers:
            x = layer(x)
            if self.dropout_rate > 0:
                x = self.encoder_dropout(x, training=True)
        z_mean = self.z_mean(x)
        z_log_var = self.z_log_var(x)
        z = self.sampling([z_mean, z_log_var])
        return z_mean, z_log_var, z

    def decode(self, z: tf.Tensor) -> tf.Tensor:
        """
        Dekodierung der latenten Variablen in rekonstruierte Daten.

        Args:
            z: Latenter Tensor der Form (Batch-Größe, latent_dim).

        Returns:
            Rekonstruierter Tensor der Form (Batch-Größe, input_dim).
        """
        x = z
        for layer in self.decoder_layers:
            x = layer(x)
            if self.dropout_rate > 0 and layer != self.decoder_layers[-1]:  # Kein Dropout in der letzten Schicht
                x = self.decoder_dropout(x, training=True)
        return self.decoder_output(x)

    def call(self, inputs: tf.Tensor, training: bool = False) -> Tuple[tf.Tensor, tf.Tensor, tf.Tensor]:
        """
        Vorwärtspass durch den VAE.

        Args:
            inputs: Eingabetensor der Form (Batch-Größe, input_dim).
            training: Boolean, der angibt, ob Trainings- oder Inferenzmodus vorliegt.

        Returns:
            Tuple[tf.Tensor, tf.Tensor, tf.Tensor]: (rekonstruiert, z_mean, z_log_var) – Rekonstruierte Daten, Mittelwert und Log-Varianz des latenten Raums.
        """
        z_mean, z_log_var, z = self.encode(inputs)
        reconstructed = self.decode(z)
        return reconstructed, z_mean, z_log_var

    def train_step(self, data: Union[tf.Tensor, Tuple[tf.Tensor, tf.Tensor]]) -> Dict[str, float]:
        """
        Trainings-Schritt für den VAE mit MSE- und KL-Verlust.

        Args:
            data: Eingabetensor der Trainingsdaten oder Tuple (x, y) für TensorFlow 2.18.

        Returns:
            Dictionary mit Metrikwerten.
        """
        if isinstance(data, tuple):
            if len(data) == 2:
                x, _ = data  # Ignoriere y, da es unüberwacht ist
            else:
                x = data[0]
        else:
            x = data

        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encode(x)
            reconstruction = self.decode(z)

            reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.square(x - reconstruction), axis=-1))
            kl_loss = -0.5 * tf.reduce_mean(tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1))
            total_loss = reconstruction_loss + self.kl_weight * kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data: Union[tf.Tensor, Tuple[tf.Tensor, tf.Tensor]]) -> Dict[str, float]:
        """
        Test-Schritt für den VAE mit MSE- und KL-Verlust.

        Args:
            data: Eingabetensor der Testdaten oder Tuple (x, y) für TensorFlow 2.18.

        Returns:
            Dictionary mit Metrikwerten.
        """
        if isinstance(data, tuple):
            if len(data) == 2:
                x, _ = data  # Ignoriere y, da es unüberwacht ist
            else:
                x = data[0]
        else:
            x = data

        z_mean, z_log_var, z = self.encode(x)
        reconstruction = self.decode(z)

        reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.square(x - reconstruction), axis=-1))
        kl_loss = -0.5 * tf.reduce_mean(tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1))
        total_loss = reconstruction_loss + self.kl_weight * kl_loss

        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "total_loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def print_summary(self):
        """
        Gibt eine Zusammenfassung der Modellarchitektur aus.

        Diese Methode verwendet die `summary()`-Methode von TensorFlow/Keras, um die Layer, Parameter und Ausgabetypen anzuzeigen.
        """
        self.summary()

    def build(self, input_shape: Tuple[int, int]) -> None:
        """
        Baut das Modell explizit mit der angegebenen Eingabeform.

        Args:
            input_shape: Tuple der Form (Batch-Größe, input_dim), wobei Batch-Größe optional ist.

        Raises:
            ValueError: Wenn input_shape kein gültiges Tuple ist.
        """
        if isinstance(input_shape, tuple) and len(input_shape) >= 1:
            input_dim = input_shape[-1]  # Nehme die letzte Dimension als input_dim
        else:
            raise ValueError("input_shape muss ein Tuple sein, z. B. (None, input_dim)")

        # Erstelle ein Dummy-Input-Tensor, um das Modell zu bauen
        dummy_input = tf.zeros((1, input_dim), dtype=tf.float32)
        self.call(dummy_input, training=False)  # Baut das Modell, indem es auf Dummy-Daten angewendet wird
    def get_config(self):
        config = super(UnsupervisedVAE, self).get_config()
        config.update({
            "input_dim": self.input_dim,
            "hidden_dims": self.hidden_dims,
            "latent_dim": self.latent_dim,
            "activation": self.activation.__name__ if callable(self.activation) else self.activation,
            "dropout_rate": self.dropout_rate,
            "kl_weight": self.kl_weight,
        })
        # Falls "build_config" hinzugefügt wurde, kannst du ihn hier optional entfernen oder zurückgeben.
        # config["build_config"] = {"input_shape": [None, self.input_dim]}
        return config

    @classmethod
    def from_config(cls, config):
        # Entferne unerwünschte Schlüssel, bevor der Konstruktor aufgerufen wird
        config.pop("build_config", None)
        return cls(**config)

# %%
uvae = UnsupervisedVAE(
    input_dim=X_train_normal.shape[1],
    latent_dim=latent_dim,
    hidden_dims=hidden_dims,
    activation=activation,
    dropout_rate=0.1,
    kl_weight=kl_weight
)
uvae.build(input_shape=(None, X_train.shape[1]))
uvae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
history_uvae = uvae.fit(
    X_train_normal,
    epochs=epoch,
    batch_size=batch_size,
    validation_split=0.1,
    verbose=0, callbacks=callbacks
)
# Ausgabe der Modellzusammenfassung
uvae.print_summary()
# Out:
# Model: "unsupervised_vae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (1, 64)                     │           1,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (1, 32)                     │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (1, 16)                     │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (1, 16)                     │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sampling (Sampling)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (1, 32)                     │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (1, 64)                     │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (1, 30)                     │           1,950 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,180 (113.99 KB)
#  Trainable params: 9,726 (37.99 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 19,454 (76.00 KB)

# %% [markdown]
# ## 2.Trainiern VAE unsupervised

# %%
# Modell speichern
save_dir = "/content/drive/MyDrive/models"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
uvae.save(os.path.join(save_dir, "UVAE.keras"))

# %%
fig, axes = plot_loss_curves(history_uvae,model_type='uvae',folder_name="vae_results")
# Out:
# Warnung: 'loss' nicht in history.history gefunden – Gesamtverlust wird nicht geplottet.
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/vae_results/loss_curves_uvae.png

# %% [markdown]
# ## 3.Rekonstruktiosnfehler berechnen

# %%
optimal_threshold_uvae, _ = find_optimal_threshold(uvae, X_test, y_test)
print(f"Optimaler Schwellenwert: {optimal_threshold_uvae}")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.0287497997283934
# Optimaler Schwellenwert: 1.0287497997283934

# %% [markdown]
# ## 4.Visualisierung der Rekonstruktionsanalyse

# %%
plot_reconstruction_analysis(
    uvae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    threshold=optimal_threshold_uvae,  # Verwende den optimalen Schwellenwert
    folder_name="vae_results"
    )
# Out:
# <ipython-input-13-198ed5571b77>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=labels, y=data, palette={'Nicht Fraud': 'blue', 'Fraud': 'red'})
# Analyse wurde gespeichert unter: /content/drive/MyDrive/vae_results/reconstruction_analysis_20250309_084837.png

# %% [markdown]
# ## 5.Visualisierung des Klassifikationsberichts

# %%
metrics_vae = evaluate_fraud_detection(
    uvae,
    X_test,
    y_test,
    save_metrics=True,  # Speichert Metriken in Google Drive
    folder_name="vae_results",
    threshold=optimal_threshold_uvae
)
# Out:
# Klassifikationsbericht:
#               precision    recall  f1-score   support
#
#  Nicht Fraud       1.00      0.95      0.97     56864
#        Fraud       0.03      0.87      0.06        98
#
#     accuracy                           0.95     56962
#    macro avg       0.51      0.91      0.52     56962
# weighted avg       1.00      0.95      0.97     56962
#
#
# Metriken:
# Precision: 0.0294
# Recall: 0.8673
# F1-Score: 0.0568
# Accuracy: 0.9504
# ROC-AUC: 0.9090
# Metriken wurden gespeichert unter: /content/drive/MyDrive/vae_results/metrics_20250309_084839.txt

# %%
fraud_predictions_uvae = detect_fraud(uvae, X_test,optimal_threshold_uvae)
plot_confusion_matrix(model="Unsupervised VAE", y_true=y_test, y_pred=fraud_predictions_uvae,folder_name="vae_results")

# %% [markdown]
# ## 6.Plot AUC ROC /AUC PR Kurve

# %%
plot_roc_auc_curve(
    uvae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="vae_results")
plot_pr_curve(
    uvae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="vae_results")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.0306932091712926
# Optimaler Schwellenwert basierend auf F1-Score: 1.0306932091712926
# ROC-Kurve wurde gespeichert unter: /content/drive/MyDrive/vae_results/UnsupervisedVAEroc_curve_20250309_084839.png
# ROC-AUC: 0.9509
# Precision-Recall-Kurve wurde gespeichert unter: /content/drive/MyDrive/vae_results/pr_curve_20250309_084840.png

# %% [markdown]
# ## 7.Plot latent space

# %%
plot_latent_space(
    uvae,
    X_test,
    np.squeeze(y_test),
    folder_name="vae_results"
)
# Out:
# Latenter Raum wurde gespeichert unter: /content/drive/MyDrive/vae_results/latent_space_UnsupervisedVAE.png

# %% [markdown]
# #III. Supervised AE

# %% [markdown]
# ## 1.Klasse SAE definieren

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, metrics, regularizers
from typing import List, Optional, Union, Tuple, Dict
@tf.keras.utils.register_keras_serializable()

class SupervisedAE(Model):
    """
    Überwachter Autoencoder für Anomalieerkennung mit Klassifikation und L2-Regularisierung für den Klassifikationsverlust.

    Args:
        input_dim (int): Dimension der Eingabedaten.
        hidden_dims (List[int]): Liste der Dimensionen der versteckten Schichten im Encoder/Decoder (Standard: [64, 32]).
        latent_dim (int): Dimension des latenten Raums (Standard: 32).
        classifier_dims (List[int]): Liste der Dimensionen der versteckten Schichten im Klassifikator (Standard: [16, 8]).
        activation (str, optional): Aktivierungsfunktion ('relu', 'mish', 'swish'). Standardwert ist 'relu'.
        dropout_rate (float, optional): Dropout-Rate zwischen 0 und 1. Standardwert ist 0.0.
        l2_lambda (float, optional): L2-Regularisierungsfaktor für den Klassifikator (Standard: 0.01).
    """
    def __init__(
        self,
        input_dim: int,
        hidden_dims: List[int] = [64, 32],
        latent_dim: int = 32,
        classifier_dims: List[int] = [16, 8],
        activation: str = 'relu',
        dropout_rate: float = 0.0,
        l2_lambda: float = 0.01  # L2-Regularisierungsfaktor für den Klassifikator
    ,**kwargs):
        super(SupervisedAE, self).__init__(**kwargs)
        self.input_dim = input_dim
        self.hidden_dims = hidden_dims
        self.latent_dim = latent_dim
        self.activation = activation
        self.dropout_rate = dropout_rate

        self.latent_dim = latent_dim
        self.dropout_rate = dropout_rate
        self.l2_lambda = l2_lambda


        # Encoder-Schichten mit optionalem Dropout
        self.encoder_layers = [
            layers.Dense(dim, activation=self.activation if callable(self.activation) else self.activation, dtype=tf.float32)
            for dim in hidden_dims
        ]
        if dropout_rate > 0:
            self.encoder_dropout = layers.Dropout(dropout_rate)

        # Latente Schicht im Encoder
        self.latent_layer = layers.Dense(latent_dim, activation=None, dtype=tf.float32)  # Keine Aktivierung für latenten Raum

        # Decoder-Schichten mit optionalem Dropout
        self.decoder_layers = [
            layers.Dense(dim, activation=self.activation if callable(self.activation) else self.activation, dtype=tf.float32)
            for dim in reversed(hidden_dims)
        ]
        if dropout_rate > 0:
            self.decoder_dropout = layers.Dropout(dropout_rate)

        self.decoder_output = layers.Dense(input_dim, activation='linear', dtype=tf.float32)

        # Klassifikator-Schichten mit L2-Regularisierung und optionalem Dropout
        self.classifier_layers = [
            layers.Dense(dim, activation=self.activation, dtype=tf.float32)
            for dim in classifier_dims
        ]
        if dropout_rate > 0:
            self.classifier_dropout = layers.Dropout(dropout_rate)

        self.classifier_output = layers.Dense(1, activation='sigmoid', dtype=tf.float32)

        # Metriken
        self.reconstruction_loss_tracker = metrics.Mean(name="reconstruction_loss", dtype=tf.float32)
        self.classification_loss_tracker = metrics.Mean(name="classification_loss", dtype=tf.float32)
        self.total_loss_tracker = metrics.Mean(name="total_loss", dtype=tf.float32)

    @property
    def metrics(self) -> List[metrics.Metric]:
        """Gibt die Liste der Metriken zurück."""
        return [
            self.reconstruction_loss_tracker,
            self.classification_loss_tracker,
            self.total_loss_tracker
        ]

    def encode(self, x: tf.Tensor) -> tf.Tensor:
        """
        Kodierung der Eingabedaten in den latenten Raum.

        Args:
            x: Eingabetensor der Form (Batch-Größe, input_dim), erwartet tf.float32.

        Returns:
            Latenter Tensor der Form (Batch-Größe, latent_dim), als tf.float32.
        """
        if x.dtype != tf.float32:
            x = tf.cast(x, tf.float32)  # Konvertiere explizit zu float32
        for layer in self.encoder_layers:
            x = layer(x)
            if self.dropout_rate > 0:
                x = self.encoder_dropout(x, training=True)
        return self.latent_layer(x)

    def decode(self, z: tf.Tensor) -> tf.Tensor:
        """
        Dekodierung der latenten Variablen in rekonstruierte Daten.

        Args:
            z: Latenter Tensor der Form (Batch-Größe, latent_dim), erwartet tf.float32.

        Returns:
            Rekonstruierter Tensor der Form (Batch-Größe, input_dim), als tf.float32.
        """
        if z.dtype != tf.float32:
            z = tf.cast(z, tf.float32)  # Konvertiere explizit zu float32
        x = z
        for layer in self.decoder_layers:
            x = layer(x)
            if self.dropout_rate > 0 and layer != self.decoder_layers[-1]:  # Kein Dropout in der letzten Schicht
                x = self.decoder_dropout(x, training=True)
        return self.decoder_output(x)

    def classify(self, z: tf.Tensor) -> tf.Tensor:
        """
        Klassifikation der latenten Variablen in Betrugswahrscheinlichkeiten.

        Args:
            z: Latenter Tensor der Form (Batch-Größe, latent_dim), erwartet tf.float32.

        Returns:
            Tensor der Form (Batch-Größe, 1) mit Wahrscheinlichkeiten (0-1), als tf.float32.
        """
        if z.dtype != tf.float32:
            z = tf.cast(z, tf.float32)  # Konvertiere explizit zu float32
        x = z
        for layer in self.classifier_layers:
            x = layer(x)
            if self.dropout_rate > 0:
                x = self.classifier_dropout(x, training=True)
        return self.classifier_output(x)

    def call(self, inputs: tf.Tensor, training: bool = False) -> Tuple[tf.Tensor, tf.Tensor]:
        """
        Vorwärtspass durch den SupervisedAE.

        Args:
            inputs: Eingabetensor der Form (Batch-Größe, input_dim), erwartet tf.float32.
            training: Boolean, der angibt, ob Trainings- oder Inferenzmodus vorliegt.

        Returns:
            Tuple[tf.Tensor, tf.Tensor]: (rekonstruiert, klassifiziert) – Rekonstruierte Daten und Klassifikationswahrscheinlichkeiten, beide als tf.float32.
        """
        if inputs.dtype != tf.float32:
            inputs = tf.cast(inputs, tf.float32)  # Konvertiere explizit zu float32
        encoded = self.encode(inputs)
        reconstructed = self.decode(encoded)
        classification = self.classify(encoded)
        return reconstructed, classification

    def train_step(self, data: Tuple[tf.Tensor, tf.Tensor]) -> Dict[str, tf.Tensor]:
        """
        Trainings-Schritt für den SupervisedAE mit MSE- und Binary Crossentropy-Verlust sowie L2-Regularisierung.

        Args:
            data: Tuple (x, y) mit Eingabedaten und Labels für TensorFlow 2.x, beide als tf.float32.

        Returns:
            Dictionary mit Metrikwerten.
        """
        x, y = data

        if x.dtype != tf.float32:
            x = tf.cast(x, tf.float32)  # Konvertiere explizit zu float32
        if y.dtype != tf.float32:
            y = tf.cast(y, tf.float32)  # Konvertiere explizit zu float32

        # Formatiere y zu Shape (batch_size, 1), um mit der Klassifikationsausgabe übereinzustimmen
        if len(y.shape) == 1:
            y = tf.expand_dims(y, axis=-1)  # Füge eine Dimension hinzu: (batch_size,) -> (batch_size, 1)

        with tf.GradientTape() as tape:
            reconstructed, classification = self(x, training=True)

            reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.square(x - reconstructed), axis=-1))
            classification_loss = tf.keras.losses.binary_crossentropy(y, classification)

            # Berechne Regularisierungsloss für den Klassifikator
            total_loss = self.l2_lambda*reconstruction_loss + tf.reduce_mean(classification_loss)

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

       # Aktualisiere die Metriken
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.classification_loss_tracker.update_state(classification_loss)
        self.total_loss_tracker.update_state(total_loss)

        return {
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "classification_loss": self.classification_loss_tracker.result(),
            "total_loss": self.total_loss_tracker.result(),
        }

    def test_step(self, data: Tuple[tf.Tensor, tf.Tensor]) -> Dict[str, tf.Tensor]:
        """
        Test-Schritt für den SupervisedAE mit MSE- und Binary Crossentropy-Verlust sowie L2-Regularisierung.

        Args:
            data: Tuple (x, y) mit Eingabedaten und Labels für TensorFlow 2.x, beide als tf.float32.

        Returns:
            Dictionary mit Metrikwerten.
        """
        x, y = data

        if x.dtype != tf.float32:
            x = tf.cast(x, tf.float32)  # Konvertiere explizit zu float32
        if y.dtype != tf.float32:
            y = tf.cast(y, tf.float32)  # Konvertiere explizit zu float32

        # Formatiere y zu Shape (batch_size, 1), um mit der Klassifikationsausgabe übereinzustimmen
        if len(y.shape) == 1:
            y = tf.expand_dims(y, axis=-1)  # Füge eine Dimension hinzu: (batch_size,) -> (batch_size, 1)

        reconstructed, classification = self(x, training=False)

        reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.square(x - reconstructed), axis=-1))
        classification_loss = tf.keras.losses.binary_crossentropy(y, classification)

        total_loss = self.l2_lambda *reconstruction_loss + tf.reduce_mean(classification_loss)

       # Aktualisiere die Metriken
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.classification_loss_tracker.update_state(classification_loss)
        self.total_loss_tracker.update_state(total_loss)

        return {
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "classification_loss": self.classification_loss_tracker.result(),
            "total_loss": self.total_loss_tracker.result(),
        }

    def print_summary(self):
        """
        Gibt eine Zusammenfassung der Modellarchitektur aus.

        Diese Methode verwendet die `summary()`-Methode von TensorFlow/Keras, um die Layer, Parameter und Ausgabetypen anzuzeigen.
        """
        self.summary()

    def build(self, input_shape: Tuple[int, int]) -> None:
        """
        Baut das Modell explizit mit der angegebenen Eingabeform.

        Args:
            input_shape: Tuple der Form (Batch-Größe, input_dim), wobei Batch-Größe optional ist.

        Raises:
            ValueError: Wenn input_shape kein gültiges Tuple ist.
        """
        if isinstance(input_shape, tuple) and len(input_shape) >= 1:
            input_dim = input_shape[-1]  # Nehme die letzte Dimension als input_dim
        else:
            raise ValueError("input_shape muss ein Tuple sein, z. B. (None, input_dim)")

        # Erstelle ein Dummy-Input-Tensor, um das Modell zu bauen
        dummy_input = tf.zeros((1, input_dim), dtype=tf.float32)
        self.call(dummy_input, training=False)  # Baut das Modell, indem es auf Dummy-Daten angewendet wird

    def get_config(self):
        config = super(SupervisedAE, self).get_config()
        config.update({
            "input_dim": self.input_dim,
            "hidden_dims": self.hidden_dims,
            "latent_dim": self.latent_dim,
            "activation": self.activation.__name__ if callable(self.activation) else self.activation,
            "dropout_rate": self.dropout_rate,
            "kl_weight": self.kl_weight,
            "l2_lambda": self.l2_lambda,
        })
        # Falls "build_config" hinzugefügt wurde, kannst du ihn hier optional entfernen oder zurückgeben.
        # config["build_config"] = {"input_shape": [None, self.input_dim]}
        return config

    @classmethod
    def from_config(cls, config):
        # Entferne unerwünschte Schlüssel, bevor der Konstruktor aufgerufen wird
        config.pop("build_config", None)
        return cls(**config)

# %%
# Aufteilung in Trainings- und Testdaten
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
# Konvertiere X und y zu float32 für TensorFlow
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

# %% [markdown]
# ## 2.Trainieren des SupervisedAE

# %%
sae = SupervisedAE(
    input_dim=X_train.shape[1],
    hidden_dims=hidden_dims,
    latent_dim=latent_dim,
    classifier_dims=classifier_dim,
    activation='mish',
    dropout_rate=0.1
)
sae.build(input_shape=(None, X_train.shape[1]))

sae.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001)
)

# %%
history_sae = sae.fit(
    X_train, y_train,  # Tuple mit X_train und y_train
    epochs=epoch,
    batch_size=batch_size,
    validation_split=0.1,
    verbose=0
)

# %%
sae.print_summary()
# Out:
# Model: "supervised_ae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_19 (Dense)                     │ (1, 64)                     │           1,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (1, 32)                     │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (1, 16)                     │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (1, 32)                     │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (1, 64)                     │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (1, 30)                     │           1,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (1, 16)                     │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (1, 8)                      │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (1, 1)                      │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 28,847 (112.69 KB)
#  Trainable params: 9,615 (37.56 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 19,232 (75.13 KB)

# %% [markdown]
# Plott alle Loss

# %%
plot_loss_curves(history_sae,model_type='sae',folder_name="sae_results")
# Out:
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/sae_results/loss_curves_sae.png
# (<Figure size 2000x800 with 3 Axes>,
#  array([<Axes: title={'center': 'Gesamtverlust'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'Rekonstruktionsverlust'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'Klassifikationsverlust'}, xlabel='Epoch', ylabel='Loss'>],
#        dtype=object))

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_fscore_support, accuracy_score

# %% [markdown]
# ## 3.Visualisierung der Rekonstruktionsanalyse

# %%
optimal_threshold_sae, _ = find_optimal_threshold(sae, X_test, y_test)
print(f"Optimaler Schwellenwert: {optimal_threshold_sae}")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 0.44727647006511684
# Optimaler Schwellenwert: 0.44727647006511684

# %%
plot_reconstruction_analysis(
    sae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="sae_results",
    threshold=optimal_threshold_sae
    )
# Out:
# <ipython-input-13-198ed5571b77>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=labels, y=data, palette={'Nicht Fraud': 'blue', 'Fraud': 'red'})
# Analyse wurde gespeichert unter: /content/drive/MyDrive/sae_results/reconstruction_analysis_20250309_085404.png

# %% [markdown]
# ## 4.Plot AUC ROC

# %%
# Evaluate the classifier on test data
_, y_pred_prob_sae = sae.predict(X_test)
y_pred_sae = (y_pred_prob_sae > 0.5).astype(int)  # Apply threshold at 0.5

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred_sae)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_sae, average='binary')

print(f"Classification Performance:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_prob_sae)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Supervised AE')
plt.legend(loc="lower right")
plt.show()
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# Classification Performance:
# Accuracy: 0.9992
# Precision: 0.8140
# Recall: 0.7143
# F1 Score: 0.7609

# %%
# Evaluate the classifier on test data
x_pred_prob_sae,_ = sae.predict(X_test)
reconstruction_error = np.mean(np.square(X_test - x_pred_prob_sae), axis=1)
mse=np.quantile(reconstruction_error,0.95)

y_pred_sae_mse = (reconstruction_error > mse).astype(int)  # Apply threshold at 0.5

# ROC Curve
fpr, tpr, _ = roc_curve(y_test,y_pred_sae_mse)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Supervised AE')
plt.legend(loc="lower right")
plt.show()
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ## Clasifikation report nach Klassifkikationclass

# %%
classification_report_sae = classification_report(y_test, y_pred_sae)
print(classification_report_sae)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     56864
#          1.0       0.81      0.71      0.76        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.86      0.88     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
classification_report_sae_mse = classification_report(y_test, y_pred_sae_mse)
print(classification_report_sae_mse)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97     56864
#          1.0       0.03      0.88      0.06        98
#
#     accuracy                           0.95     56962
#    macro avg       0.51      0.91      0.52     56962
# weighted avg       1.00      0.95      0.97     56962

# %%
plot_confusion_matrix(model="Supervised AE",y_true=y_test,y_pred=y_pred_sae,folder_name="sae_results")

# %% [markdown]
# ## 5.Plot latent space

# %%
# Extract the latent representations
plot_latent_space(sae, X_test, y_test, folder_name="sae_results")
# Out:
# Latenter Raum wurde gespeichert unter: /content/drive/MyDrive/sae_results/latent_space_SupervisedAE.png

# %% [markdown]
# #IV. Supervised VAE

# %% [markdown]
# ##1.Klasse SVAE def

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, metrics
from typing import List, Optional, Union, Tuple, Dict
@tf.keras.utils.register_keras_serializable()

class SupervisedVAE(Model):
    """
    Überwachter Variational Autoencoder für Anomalieerkennung mit Klassifikation.

    Args:
        input_dim (int): Dimension der Eingabedaten.
        hidden_dims (List[int]): Liste der Dimensionen der versteckten Schichten im Encoder/Decoder (Standard: [64, 32]).
        latent_dim (int): Dimension des latenten Raums (Standard: 16).
        classifier_dims (List[int]): Liste der Dimensionen der versteckten Schichten im Klassifikator (Standard: [16]).
        activation (str, optional): Aktivierungsfunktion ('relu', 'mish', 'swish'). Standardwert ist 'relu'.
        dropout_rate (float, optional): Dropout-Rate zwischen 0 und 1. Standardwert ist 0.0.
        kl_weight (float, optional): Gewichtungsfaktor für den KL-Verlust. Standardwert ist 1.0.
    """
    def __init__(
               self,
        input_dim: int,
        hidden_dims: List[int] = [64, 32],
        latent_dim: int = 32,
        classifier_dims: List[int] = [16, 8],
        activation: str = 'relu',
        dropout_rate: float = 0.0,
        l2_lambda: float = 0.01,
        kl_weight: float = 1.0
    ,**kwargs):
        super(SupervisedVAE, self).__init__(**kwargs)
        self.input_dim = input_dim
        self.hidden_dims = hidden_dims
        self.latent_dim = latent_dim
        self.activation = activation
        self.dropout_rate = dropout_rate
        self.latent_dim = latent_dim
        self.dropout_rate = dropout_rate
        self.kl_weight = kl_weight
        self.l2_lambda = l2_lambda

        # Encoder-Schichten mit optionalem Dropout
        self.encoder_layers = [
            layers.Dense(dim, activation=self.activation if callable(self.activation) else self.activation, dtype=tf.float32)
            for dim in hidden_dims
        ]
        if dropout_rate > 0:
            self.encoder_dropout = layers.Dropout(dropout_rate)

        self.z_mean = layers.Dense(latent_dim, dtype=tf.float32)
        self.z_log_var = layers.Dense(latent_dim, dtype=tf.float32)

        class Sampling(layers.Layer):
            def call(self, inputs: Tuple[tf.Tensor, tf.Tensor]) -> tf.Tensor:
                z_mean, z_log_var = inputs
                batch = tf.shape(z_mean)[0]
                dim = tf.shape(z_mean)[1]
                epsilon = tf.random.normal(shape=(batch, dim), dtype=tf.float32)
                return z_mean + tf.exp(0.5 * z_log_var) * epsilon

        self.sampling = Sampling()

        # Decoder-Schichten mit optionalem Dropout
        self.decoder_layers = [
            layers.Dense(dim, activation=self.activation if callable(self.activation) else self.activation, dtype=tf.float32)
            for dim in reversed(hidden_dims)
        ]
        if dropout_rate > 0:
            self.decoder_dropout = layers.Dropout(dropout_rate)

        self.decoder_output = layers.Dense(input_dim, activation='linear', dtype=tf.float32)

         # Klassifikator-Schichten und optionalem Dropout
        self.classifier_layers = [
            layers.Dense(dim, activation=self.activation, dtype=tf.float32)
            for dim in classifier_dims
        ]
        if dropout_rate > 0:
            self.classifier_dropout = layers.Dropout(dropout_rate)
        self.classifier_output = layers.Dense(1, activation='sigmoid', dtype=tf.float32)

        # Metriken
        self.reconstruction_loss_tracker = metrics.Mean(name="reconstruction_loss", dtype=tf.float32)
        self.classification_loss_tracker = metrics.Mean(name="classification_loss", dtype=tf.float32)
        self.kl_loss_tracker = metrics.Mean(name="kl_loss", dtype=tf.float32)
        self.total_loss_tracker = metrics.Mean(name="total_loss", dtype=tf.float32)

    @property
    def metrics(self) -> List[metrics.Metric]:
        """Gibt die Liste der Metriken zurück."""
        return [
            self.reconstruction_loss_tracker,
            self.classification_loss_tracker,
            self.kl_loss_tracker,
            self.total_loss_tracker,
        ]

    def encode(self, x: tf.Tensor) -> Tuple[tf.Tensor, tf.Tensor, tf.Tensor]:
        """
        Kodierung der Eingabedaten in den latenten Raum.

        Args:
            x: Eingabetensor der Form (Batch-Größe, input_dim), erwartet tf.float32.

        Returns:
            Tuple[tf.Tensor, tf.Tensor, tf.Tensor]: (z_mean, z_log_var, z) – Mittelwert, Log-Varianz und gestochastische latente Variable, alle als tf.float32.
        """
        if x.dtype != tf.float32:
            x = tf.cast(x, tf.float32)  # Konvertiere explizit zu float32
        for layer in self.encoder_layers:
            x = layer(x)
            if self.dropout_rate > 0:
                x = self.encoder_dropout(x, training=True)
        z_mean = self.z_mean(x)
        z_log_var = self.z_log_var(x)
        z = self.sampling([z_mean, z_log_var])
        return z_mean, z_log_var, z

    def decode(self, z: tf.Tensor) -> tf.Tensor:
        """
        Dekodierung der latenten Variablen in rekonstruierte Daten.

        Args:
            z: Latenter Tensor der Form (Batch-Größe, latent_dim), erwartet tf.float32.

        Returns:
            Rekonstruierter Tensor der Form (Batch-Größe, input_dim), als tf.float32.
        """
        if z.dtype != tf.float32:
            z = tf.cast(z, tf.float32)  # Konvertiere explizit zu float32
        x = z
        for layer in self.decoder_layers:
            x = layer(x)
            if self.dropout_rate > 0 and layer != self.decoder_layers[-1]:  # Kein Dropout in der letzten Schicht
                x = self.decoder_dropout(x, training=True)
        return self.decoder_output(x)

    def classify(self, z: tf.Tensor) -> tf.Tensor:
        """
        Klassifikation der latenten Variablen in Betrugswahrscheinlichkeiten.

        Args:
            z: Latenter Tensor der Form (Batch-Größe, latent_dim), erwartet tf.float32.

        Returns:
            Tensor der Form (Batch-Größe, 1) mit Wahrscheinlichkeiten (0-1), als tf.float32.
        """
        if z.dtype != tf.float32:
            z = tf.cast(z, tf.float32)  # Konvertiere explizit zu float32
        x = z
        for layer in self.classifier_layers:
            x = layer(x)
            if self.dropout_rate > 0:
                x = self.classifier_dropout(x, training=True)
        return self.classifier_output(x)

    def call(self, inputs: tf.Tensor, training: bool = False) -> Tuple[tf.Tensor, tf.Tensor, tf.Tensor, tf.Tensor]:
        """
        Vorwärtspass durch den SupervisedVAE.

        Args:
            inputs: Eingabetensor der Form (Batch-Größe, input_dim), erwartet tf.float32.
            training: Boolean, der angibt, ob Trainings- oder Inferenzmodus vorliegt.

        Returns:
            Tuple[tf.Tensor, tf.Tensor, tf.Tensor, tf.Tensor]: (rekonstruiert, z_mean, z_log_var, klassifiziert) – Rekonstruierte Daten, Mittelwert, Log-Varianz des latenten Raums und Klassifikationswahrscheinlichkeiten, alle als tf.float32.
        """
        if inputs.dtype != tf.float32:
            inputs = tf.cast(inputs, tf.float32)  # Konvertiere explizit zu float32
        z_mean, z_log_var, z = self.encode(inputs)
        reconstructed = self.decode(z)
        classification = self.classify(z_mean)  # Verwende z_mean für Klassifikation
        return reconstructed, z_mean, z_log_var, classification

    def train_step(self, data: Tuple[tf.Tensor, tf.Tensor]) -> Dict[str, float]:
        """
        Trainings-Schritt für den SupervisedVAE mit MSE-, Binary Crossentropy- und KL-Verlust.
        """
        # Debugging und Datenextraktion (wie zuvor)
        x, y = data
        if x.dtype != tf.float32:
            x = tf.cast(x, tf.float32)
        if y.dtype != tf.float32:
            y = tf.cast(y, tf.float32)
        if len(y.shape) == 1:
            y = tf.expand_dims(y, axis=-1)

        with tf.GradientTape() as tape:
            reconstructed, z_mean, z_log_var, classification = self.call(x, training=True)

            # Rekonstruktionsverlust (MSE)
            reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.square(x - reconstructed), axis=-1))

            # Klassifikationsverlust (Binary Crossentropy)
            classification_loss = tf.keras.losses.binary_crossentropy(y, classification)

            # KL-Verlust
            kl_loss = -0.5 * tf.reduce_mean(tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1))

            # Gesamtverlust
            total_loss = self.l2_lambda*reconstruction_loss + tf.reduce_mean(classification_loss) + self.kl_weight * kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        # Aktualisiere Metriken, einschließlich 'loss'
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.classification_loss_tracker.update_state(classification_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        self.total_loss_tracker.update_state(total_loss)  # Speichere 'loss' als total_loss

        return {
            "total_loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "classification_loss": self.classification_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data: Tuple[tf.Tensor, tf.Tensor]) -> Dict[str, float]:
        """
        Test-Schritt für den SupervisedVAE mit MSE-, Binary Crossentropy- und KL-Verlust.

        Args:
            data: Tuple (x, y) mit Eingabedaten und Labels für TensorFlow 2.18, beide als tf.float32.

        Returns:
            Dictionary mit Metrikwerten.
        """
        x, y = data

        if x.dtype != tf.float32:
            x = tf.cast(x, tf.float32)  # Konvertiere explizit zu float32
        if y.dtype != tf.float32:
            y = tf.cast(y, tf.float32)  # Konvertiere explizit zu float32

        # Formatiere y zu Shape (batch_size, 1), um mit der Klassifikationsausgabe übereinzustimmen
        if len(y.shape) == 1:
            y = tf.expand_dims(y, axis=-1)  # Füge eine Dimension hinzu: (batch_size,) -> (batch_size, 1)

        reconstructed, z_mean, z_log_var, classification = self.call(x, training=False)

        # Rekonstruktionsverlust (MSE)
        reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.square(x - reconstructed), axis=-1))

        # Klassifikationsverlust (Binary Crossentropy)
        classification_loss = tf.keras.losses.binary_crossentropy(y, classification)

        # KL-Verlust
        kl_loss = -0.5 * tf.reduce_mean(tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1))

        # Gesamtverlust
        total_loss = reconstruction_loss + tf.reduce_mean(classification_loss) + self.kl_weight * kl_loss

        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.classification_loss_tracker.update_state(classification_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        self.total_loss_tracker.update_state(total_loss)  # Speichere 'loss' als total_loss

        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "classification_loss": self.classification_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def print_summary(self):
        """
        Gibt eine Zusammenfassung der Modellarchitektur aus.

        Diese Methode verwendet die `summary()`-Methode von TensorFlow/Keras, um die Layer, Parameter und Ausgabetypen anzuzeigen.
        """
        self.summary()

    def build(self, input_shape: Tuple[int, int]) -> None:
        """
        Baut das Modell explizit mit der angegebenen Eingabeform.

        Args:
            input_shape: Tuple der Form (Batch-Größe, input_dim), wobei Batch-Größe optional ist.

        Raises:
            ValueError: Wenn input_shape kein gültiges Tuple ist.
        """
        if isinstance(input_shape, tuple) and len(input_shape) >= 1:
            input_dim = input_shape[-1]  # Nehme die letzte Dimension als input_dim
        else:
            raise ValueError("input_shape muss ein Tuple sein, z. B. (None, input_dim)")

        # Erstelle ein Dummy-Input-Tensor, um das Modell zu bauen
        dummy_input = tf.zeros((1, input_dim), dtype=tf.float32)
        self.call(dummy_input, training=False)  # Baut das Modell, indem es auf Dummy-Daten angewendet wird

    def get_config(self):
        config = super(SupervisedVAE, self).get_config()
        config.update({
            "input_dim": self.input_dim,
            "hidden_dims": self.hidden_dims,
            "latent_dim": self.latent_dim,
            "activation": self.activation.__name__ if callable(self.activation) else self.activation,
            "dropout_rate": self.dropout_rate,
            "kl_weight": self.kl_weight,
            "l2_lambda": self.l2_lambda,
        })
        # Falls "build_config" hinzugefügt wurde, kannst du ihn hier optional entfernen oder zurückgeben.
        # config["build_config"] = {"input_shape": [None, self.input_dim]}
        return config

    @classmethod
    def from_config(cls, config):
        # Entferne unerwünschte Schlüssel, bevor der Konstruktor aufgerufen wird
        config.pop("build_config", None)
        return cls(**config)

# %%
# Konvertiere X und y zu float32 für TensorFlow und forme y zu (batch_size, 1)
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = np.expand_dims(y_train.astype(np.float32), axis=-1)  # Shape (n_samples, 1)
y_test = np.expand_dims(y_test.astype(np.float32), axis=-1)    # Shape (n_samples, 1)

# Debugging-Ausgabe, um die Formate zu überprüfen
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("y_train unique values:", np.unique(y_train))
print("y_train dtype:", y_train.dtype)
print("X_train dtype:", X_train.dtype)
# Out:
# X_train shape: (227845, 30)
# y_train shape: (227845, 1)
# y_train unique values: [0. 1.]
# y_train dtype: float32
# X_train dtype: float32

# %% [markdown]
# ## 2.Trainieren

# %%
svae = SupervisedVAE(
    input_dim=X_train.shape[1],
    hidden_dims=hidden_dims,
    latent_dim=latent_dim,
    classifier_dims=classifier_dim,
    activation=activation,
    dropout_rate=dropout_rate,
    kl_weight=kl_weight
)
sae.build(input_shape=(None, X_train.shape[1]))

svae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

# %%
history_svae = svae.fit(
    X_train, y_train,  # Tuple mit X_train und y_train
    epochs=epoch,
    validation_split=0.1,
    verbose=0
)

# %%
# Ausgabe der Modellzusammenfassung
svae.print_summary()
# Out:
# Model: "supervised_vae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_28 (Dense)                     │ (None, 64)                  │           1,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_30 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_31 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sampling_1 (Sampling)                │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 30)                  │           1,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_37 (Dense)                     │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,431 (118.88 KB)
#  Trainable params: 10,143 (39.62 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 20,288 (79.25 KB)

# %%
# Bestimmen des optimalen Schwellenwerts
optimal_threshold, _ = find_optimal_threshold(svae, X_test, np.squeeze(y_test))  # Squeeze y_test, um (n_samples,) zu erhalten
print(f"Optimaler Schwellenwert basierend auf F1-Score: {optimal_threshold}")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.9625055789947499
# Optimaler Schwellenwert basierend auf F1-Score: 1.9625055789947499

# %% [markdown]
# ## 3.Visualisireung der Rekonstruktionsanalyse

# %%
plot_loss_curves(history_svae,model_type="svae", folder_name="svae_results/loss_curves")
# Out:
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/svae_results/loss_curves/loss_curves_svae.png
# (<Figure size 2000x800 with 4 Axes>,
#  array([<Axes: title={'center': 'Gesamtverlust'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'Rekonstruktionsverlust'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'KL-Divergenz'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'Klassifikationsverlust'}, xlabel='Epoch', ylabel='Loss'>],
#        dtype=object))

# %%
plot_reconstruction_analysis(
    svae,
    X_test,
    np.squeeze(y_test),  # Squeeze y_test, um (n_samples,) zu erhalten
    threshold=optimal_threshold,
    folder_name="svae_results/reconstruction_analysis"
)
# Out:
# <ipython-input-13-198ed5571b77>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=labels, y=data, palette={'Nicht Fraud': 'blue', 'Fraud': 'red'})
# Analyse wurde gespeichert unter: /content/drive/MyDrive/svae_results/reconstruction_analysis/reconstruction_analysis_20250309_092406.png

# %% [markdown]
# ##4. Plot AUC ROC

# %%
# Evaluate the classifier on test data
_,_,_, y_pred_prob_svae = svae.predict(X_test)
y_pred_svae = (y_pred_prob_svae > 0.5).astype(int)  # Apply threshold at 0.5

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred_svae)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_svae, average='binary')

print(f"Classification Performance:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_prob_svae)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# Classification Performance:
# Accuracy: 0.9992
# Precision: 0.7841
# Recall: 0.7041
# F1 Score: 0.7419

# %% [markdown]
# ## Classifikation report

# %%
classification_report_svae = classification_report(y_test, y_pred_svae)
print(classification_report_svae)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     56864
#          1.0       0.78      0.70      0.74        98
#
#     accuracy                           1.00     56962
#    macro avg       0.89      0.85      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# ## 5.Plotten des latenten Raums

# %%
plot_latent_space(
    svae,
    X_test,
    np.squeeze(y_test),  # Squeeze y_test, um (n_samples,) zu erhalten
    folder_name="svae_results/latent_space"
)
# Out:
# Latenter Raum wurde gespeichert unter: /content/drive/MyDrive/svae_results/latent_space/latent_space_SupervisedVAE.png

# %%
plot_confusion_matrix(model="Supervised VAE",y_true=y_test,y_pred=y_pred_svae,folder_name="sae_results")

# %% [markdown]
# _______________________________________________________
#
# ---

# %%
def train_and_plot_model(model_class, model_type, X_train, y_train, X_test, y_test):
    learning_rate = 0.001  # Definieren Sie den Lernrate-Wert
    if model_type in ['uae', 'uvae']:
        # Für unüberwachte Modelle: Nur normale Daten (Class=0) verwenden
        X_train_normal = X_train[y_train.flatten() == 0]
        model = model_class(
            input_dim=X_train.shape[1],
            latent_dim=16,
            hidden_dims=[64, 32],
            activation='mish',
            dropout_rate=0.1
        )
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
        history = model.fit(X_train_normal, epochs=5, batch_size=256,validation_split=0.1, verbose=0)
    else:  # 'sae', 'svae'
        model = model_class(
            input_dim=X_train.shape[1],
            hidden_dims=[64, 32],
            latent_dim=16,
            classifier_dims=[16],
            activation='mish',
            dropout_rate=0.1
        )
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
        history = model.fit(X_train,y_train, epochs=5, validation_split=0.1, verbose=0)

    # Plotten der Loss-Kurven
    fig, axes = plot_loss_curves(
        history,
        model_type=model_type,
        folder_name="all_results/loss_curves"
    )
    #model.save_model_to_drive()

# %%
# Trainieren und plotten für jedes Modell
for model_class, model_type in [
    (UnsupervisedAE, 'uae'),
    (UnsupervisedVAE, 'uvae'),
    (SupervisedAE, 'sae'),
    (SupervisedVAE, 'svae')
]:
    print(f"\nTraining und Plotten für {model_type.upper()}...")
    train_and_plot_model(model_class, model_type, X_train, y_train, X_test, y_test)
# Out:
# Training und Plotten für UAE...
# Warnung: 'loss' nicht in history.history gefunden – Gesamtverlust wird nicht geplottet.
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/all_results/loss_curves/loss_curves_uae_20250301_093813.png
#
# Training und Plotten für UVAE...
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/all_results/loss_curves/loss_curves_uvae_20250301_093857.png
#
# Training und Plotten für SAE...
# Warnung: 'loss' nicht in history.history gefunden – Gesamtverlust wird nicht geplottet.
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/all_results/loss_curves/loss_curves_sae_20250301_094229.png
#
# Training und Plotten für SVAE...
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/all_results/loss_curves/loss_curves_svae_20250301_094501.png

# %% [markdown]
# # VI. Hyperparameter-Tuining

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.38)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 8.1 MB/s eta 0:00:00
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 20.9 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.9 alembic-1.14.1 colorlog-6.9.0 optuna-4.2.1

# %%
import optuna
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ## Hilffunktion um Modell zu erstellen

# %%
def create_model(model_class, latent_dim, activation, dropout_rate, kl_weight=None, classifier_dims=None,l2_lambda=None):
    if model_class ==UnsupervisedVAE:
        return model_class(
            input_dim=X_train.shape[1],
            hidden_dims=[64, 32],
            latent_dim=latent_dim,
            activation=activation,
            dropout_rate=dropout_rate,
            kl_weight=kl_weight if kl_weight is not None else 1.0
        )
    elif model_class == SupervisedAE:
        return model_class(
            input_dim=X_train.shape[1],
            hidden_dims=[64, 32],
            latent_dim=latent_dim,
            classifier_dims=classifier_dims,  # Einzelne Schicht für SAE
            activation=activation,
            dropout_rate=dropout_rate,
            l2_lambda=l2_lambda
        )
    elif model_class == SupervisedVAE:
         return model_class(
            input_dim=X_train.shape[1],
            hidden_dims=[64, 32],
            latent_dim=latent_dim,
            activation=activation,
            dropout_rate=dropout_rate,
            kl_weight=kl_weight if kl_weight is not None else 1.0,
            l2_lambda=l2_lambda
        )
    else:  # UnsupervisedAE
        return model_class(
            input_dim=X_train.shape[1],
            hidden_dims=[64, 32],
            latent_dim=latent_dim,
            activation=activation,
            dropout_rate=dropout_rate
        )

# %% [markdown]
# ## Optuna-Studien für jedes Modell

# %%
# StratifiedKFold für Kreuzvalidierung (5 Folds)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

print("Daten vorbereitet. Shapes:", X_train.shape, y_train.shape)
# Out:
# Daten vorbereitet. Shapes: (227845, 30) (227845,)

# %%
# Dictionary zur Speicherung der besten Parameter
best_params_dict = {}

# %%
import json # Import the json module
from sklearn.model_selection import StratifiedKFold

# %%
# Dictionary zur Speicherung der besten Parameter
best_params_dict = {}

# Optimierung nur für UnsupervisedAE
model_class = UnsupervisedAE
model_type = 'uae'
model_name = model_class.__name__
print(f"\nStarte Hyperparameter-Optimierung mit Optuna für {model_name} (ROC-AUC mit StratifiedKFold)...")

pruner = optuna.pruners.HyperbandPruner(
    min_resource=5,    # Mindestanzahl von Epochen
    max_resource=30,   # Maximalanzahl von Epochen
    reduction_factor=3 # Reduktionsfaktor für Ressourcenzuweisung
)
# Erstelle eine Optuna-Studie
study_uae = optuna.create_study(direction='maximize', pruner=pruner)
def objective_ae(trial):
    # Hyperparameter-Suchraum
    latent_dim = trial.suggest_categorical('latent_dim', [2, 8, 16])
    activation = trial.suggest_categorical('activation', ['relu', 'mish',"swish"])
    learning_rate = trial.suggest_float('learning_rate', 0.001, 0.01, log=True)
    dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.2)

    # Initialisiere ROC-AUC über die Folds
    roc_auc_scores = []

    # StratifiedKFold für robuste Evaluierung
    for train_idx, val_idx in skf.split(X_train, y_train.flatten()):
        X_train_fold = X_train[train_idx]
        y_train_fold = y_train[train_idx]
        X_val_fold = X_train[val_idx]
        y_val_fold = y_train[val_idx]

        # Erstelle und kompiliere das Modell
        model = create_model(model_class,latent_dim, activation, dropout_rate)
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

        # Baue das Modell
        X_train_normal_fold = X_train_fold[y_train_fold.flatten() == 0]
        if len(X_train_normal_fold) == 0:
            raise ValueError("Keine normalen Daten gefunden!")
        model.build(input_shape=(None, X_train_normal_fold.shape[1]))
        history = model.fit(X_train_normal_fold, epochs=10, batch_size=64, validation_data=(X_val_fold[y_val_fold.flatten() == 0], None), verbose=0)

        # Berechne Rekonstruktionsfehler für Validierungsdaten
        recon_error = calculate_reconstruction_error(model, X_val_fold)
        if np.any(np.isnan(recon_error)):
            recon_error = np.nan_to_num(recon_error, nan=np.mean(recon_error))
        roc_auc = roc_auc_score(y_val_fold.flatten(), recon_error)

        roc_auc_scores.append(roc_auc)

    # Rückgabe des durchschnittlichen ROC-AUC über alle Folds
    mean_roc_auc = np.mean(roc_auc_scores)
    return mean_roc_auc


# Führe 20 Trials durch
study_uae.optimize(objective_ae, n_trials=10)

# Speichere die besten Parameter
best_params = study_uae.best_params
best_params_dict[model_name] = best_params
print(f"Beste Parameter für {model_name}: {best_params}")
print(f"Bester durchschnittlicher ROC-AUC (5-Fold): {study_uae.best_value:.4f}")
# Out:
# [I 2025-03-03 06:15:16,862] A new study created in memory with name: no-name-c2f4ee0c-fc10-4a3d-8f3e-a517f9ee3153
# Starte Hyperparameter-Optimierung mit Optuna für UnsupervisedAE (ROC-AUC mit StratifiedKFold)...
# [I 2025-03-03 06:21:33,702] Trial 0 finished with value: 0.9522820770072624 and parameters: {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.0012307305323363289, 'dropout_rate': 0.05117046012607634}. Best is trial 0 with value: 0.9522820770072624.
# [I 2025-03-03 06:27:41,577] Trial 1 finished with value: 0.9516027691155491 and parameters: {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.0017449758431955372, 'dropout_rate': 0.028462774184458462}. Best is trial 0 with value: 0.9522820770072624.
# [I 2025-03-03 06:33:53,114] Trial 2 finished with value: 0.9531730271518667 and parameters: {'latent_dim': 2, 'activation': 'swish', 'learning_rate': 0.0036884550320333475, 'dropout_rate': 0.14438827330883364}. Best is trial 2 with value: 0.9531730271518667.
# [I 2025-03-03 06:40:00,735] Trial 3 finished with value: 0.9520036180621609 and parameters: {'latent_dim': 16, 'activation': 'swish', 'learning_rate': 0.009142154836001946, 'dropout_rate': 0.08373442050018493}. Best is trial 2 with value: 0.9531730271518667.
# [I 2025-03-03 06:46:12,471] Trial 4 finished with value: 0.953050446470758 and parameters: {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.0034482437155889606, 'dropout_rate': 0.16069822052874128}. Best is trial 2 with value: 0.9531730271518667.
# [I 2025-03-03 06:52:22,378] Trial 5 finished with value: 0.9522400029554439 and parameters: {'latent_dim': 16, 'activation': 'relu', 'learning_rate': 0.0016362631508579375, 'dropout_rate': 0.09392525225854186}. Best is trial 2 with value: 0.9531730271518667.
# [I 2025-03-03 06:58:32,991] Trial 6 finished with value: 0.9511569817376412 and parameters: {'latent_dim': 16, 'activation': 'swish', 'learning_rate': 0.009091922946468758, 'dropout_rate': 0.12585263086154239}. Best is trial 2 with value: 0.9531730271518667.
# [I 2025-03-03 07:04:47,132] Trial 7 finished with value: 0.9524802607116246 and parameters: {'latent_dim': 2, 'activation': 'mish', 'learning_rate': 0.005136497079640407, 'dropout_rate': 0.004454150728547446}. Best is trial 2 with value: 0.9531730271518667.
# [I 2025-03-03 07:10:58,016] Trial 8 finished with value: 0.9531684832216152 and parameters: {'latent_dim': 8, 'activation': 'swish', 'learning_rate': 0.0040403427703875954, 'dropout_rate': 0.161496189935128}. Best is trial 2 with value: 0.9531730271518667.
# [I 2025-03-03 07:17:09,599] Trial 9 finished with value: 0.9519222288376674 and parameters: {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.005832775909554932, 'dropout_rate': 0.17665613482707374}. Best is trial 2 with value: 0.9531730271518667.
# Beste Parameter für UnsupervisedAE: {'latent_dim': 2, 'activation': 'swish', 'learning_rate': 0.0036884550320333475, 'dropout_rate': 0.14438827330883364}
# Bester durchschnittlicher ROC-AUC (5-Fold): 0.9532

# %%
import matplotlib.pyplot as plt

# UAE

optuna.visualization.matplotlib.plot_optimization_history(study_uae)
optuna.visualization.matplotlib.plot_param_importances(study_uae)
fig.show()
# Out:
# <ipython-input-110-ef3f2df0c054>:5: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_uae)
# <ipython-input-110-ef3f2df0c054>:6: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study_uae)

# %% [markdown]
# ## Optuna VAE

# %%
# Dictionary zur Speicherung der besten Parameter
# Optimierung nur für UnsupervisedAE
model_class = UnsupervisedVAE
model_type = 'uvae'
model_name = model_class.__name__
print(f"\nStarte Hyperparameter-Optimierung mit Optuna für {model_name} (ROC-AUC mit StratifiedKFold)...")

# Erstelle eine Optuna-Studie
study_uvae = optuna.create_study(direction='maximize', pruner=pruner)
def objective_uvae(trial):
    # Hyperparameter-Suchraum
    latent_dim = trial.suggest_categorical('latent_dim', [2, 8, 16])
    activation = trial.suggest_categorical('activation', ['relu', 'mish',"swish"])
    learning_rate = trial.suggest_float('learning_rate', 0.0001, 0.01, log=True)
    dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.2)
    kl_weight = trial.suggest_float('kl_weight', 0.5, 2.0)
    # Initialisiere ROC-AUC über die Folds
    roc_auc_scores = []

    # StratifiedKFold für robuste Evaluierung
    for train_idx, val_idx in skf.split(X_train, y_train.flatten()):
        X_train_fold = X_train[train_idx]
        y_train_fold = y_train[train_idx]
        X_val_fold = X_train[val_idx]
        y_val_fold = y_train[val_idx]

        # Erstelle und kompiliere das Modell
        model = create_model(model_class,latent_dim, activation, dropout_rate,kl_weight)
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

        # Baue das Modell
        X_train_normal_fold = X_train_fold[y_train_fold.flatten() == 0]
        if len(X_train_normal_fold) == 0:
            raise ValueError("Keine normalen Daten gefunden!")
        model.build(input_shape=(None, X_train_normal_fold.shape[1]))
        history = model.fit(X_train_normal_fold, epochs=10, batch_size=64, validation_data=(X_val_fold[y_val_fold.flatten() == 0], None), verbose=0)

        # Berechne Rekonstruktionsfehler für Validierungsdaten
        recon_error = calculate_reconstruction_error(model, X_val_fold)
        if np.any(np.isnan(recon_error)):
            recon_error = np.nan_to_num(recon_error, nan=np.finfo(recon_error.dtype).max)
        roc_auc = roc_auc_score(y_val_fold.flatten(), recon_error)

        roc_auc_scores.append(roc_auc)

    # Rückgabe des durchschnittlichen ROC-AUC über alle Folds
    mean_roc_auc = np.mean(roc_auc_scores)
    return mean_roc_auc


# Führe 10 Trials durch
study_uvae.optimize(objective_uvae, n_trials=10)

# Speichere die besten Parameter
best_params = study_uvae.best_params
best_params_dict[model_name] = best_params
print(f"Beste Parameter für {model_name}: {best_params}")
print(f"Bester durchschnittlicher ROC-AUC (5-Fold): {study_uvae.best_value:.4f}")
# Out:
# [I 2025-03-03 07:19:31,032] A new study created in memory with name: no-name-a26fac9d-6081-4ef2-8f36-5f2cde84b6fe
# Starte Hyperparameter-Optimierung mit Optuna für UnsupervisedVAE (ROC-AUC mit StratifiedKFold)...
# [I 2025-03-03 07:26:47,441] Trial 0 finished with value: 0.9516881039962015 and parameters: {'latent_dim': 16, 'activation': 'relu', 'learning_rate': 0.0007933113978739781, 'dropout_rate': 0.01867294353448019, 'kl_weight': 1.7450378876913712}. Best is trial 0 with value: 0.9516881039962015.
# [I 2025-03-03 07:34:00,632] Trial 1 finished with value: 0.9530032219656555 and parameters: {'latent_dim': 8, 'activation': 'relu', 'learning_rate': 0.00038570299008967895, 'dropout_rate': 0.15289671531593407, 'kl_weight': 1.042017712647616}. Best is trial 1 with value: 0.9530032219656555.
# [I 2025-03-03 07:41:19,193] Trial 2 finished with value: 0.8617928565316507 and parameters: {'latent_dim': 8, 'activation': 'relu', 'learning_rate': 0.0001134043907766988, 'dropout_rate': 0.19756145248154822, 'kl_weight': 1.9792692341109297}. Best is trial 1 with value: 0.9530032219656555.
# [I 2025-03-03 07:48:35,552] Trial 3 finished with value: 0.9513585355076268 and parameters: {'latent_dim': 16, 'activation': 'relu', 'learning_rate': 0.001173102282900512, 'dropout_rate': 0.00778508976645127, 'kl_weight': 1.1512680611965844}. Best is trial 1 with value: 0.9530032219656555.
# [I 2025-03-03 07:55:48,248] Trial 4 finished with value: 0.9532103077030994 and parameters: {'latent_dim': 16, 'activation': 'swish', 'learning_rate': 0.00026814821432734467, 'dropout_rate': 0.08227562050756912, 'kl_weight': 1.91061616139928}. Best is trial 4 with value: 0.9532103077030994.
# [I 2025-03-03 08:02:58,023] Trial 5 finished with value: 0.9509201007845997 and parameters: {'latent_dim': 16, 'activation': 'relu', 'learning_rate': 0.006589873878868379, 'dropout_rate': 0.1522617554249439, 'kl_weight': 1.8810931629595795}. Best is trial 4 with value: 0.9532103077030994.
# [I 2025-03-03 08:10:25,677] Trial 6 finished with value: 0.9534967222218633 and parameters: {'latent_dim': 2, 'activation': 'swish', 'learning_rate': 0.00022252325857421317, 'dropout_rate': 0.07061057411978693, 'kl_weight': 1.2003344773811349}. Best is trial 6 with value: 0.9534967222218633.
# [I 2025-03-03 08:17:41,796] Trial 7 finished with value: 0.9437159839388725 and parameters: {'latent_dim': 2, 'activation': 'swish', 'learning_rate': 0.004406350407417279, 'dropout_rate': 0.10795807575601256, 'kl_weight': 1.1289964308993545}. Best is trial 6 with value: 0.9534967222218633.
# [I 2025-03-03 08:24:59,470] Trial 8 finished with value: 0.9443324781628517 and parameters: {'latent_dim': 8, 'activation': 'mish', 'learning_rate': 0.0026978505232863785, 'dropout_rate': 0.05877660281122581, 'kl_weight': 1.4739375900036538}. Best is trial 6 with value: 0.9534967222218633.
# [I 2025-03-03 08:32:16,947] Trial 9 finished with value: 0.9514845542749312 and parameters: {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.0017332283777032294, 'dropout_rate': 0.08213553204392228, 'kl_weight': 1.1829080907333243}. Best is trial 6 with value: 0.9534967222218633.
# Beste Parameter für UnsupervisedVAE: {'latent_dim': 2, 'activation': 'swish', 'learning_rate': 0.00022252325857421317, 'dropout_rate': 0.07061057411978693, 'kl_weight': 1.2003344773811349}
# Bester durchschnittlicher ROC-AUC (5-Fold): 0.9535

# %%
# UAE
#axes[0, 0].set_title('UAE Hyperparameter Optimization')
optuna.visualization.matplotlib.plot_optimization_history(study_uvae)
optuna.visualization.matplotlib.plot_param_importances(study_uvae)
fig.show()
# Out:
# <ipython-input-114-49c674ae2dd0>:3: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_uvae)
# <ipython-input-114-49c674ae2dd0>:4: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study_uvae)

# %% [markdown]
# ## Optuna mit SAE

# %%
classifier_dims = [16,8]
# Optimierung nur für SupervisedAE
model_class = SupervisedAE
model_type = 'sae'
model_name = model_class.__name__
print(f"\nStarte Hyperparameter-Optimierung mit Optuna für {model_name} (ROC-AUC mit StratifiedKFold)...")

# Erstelle eine Optuna-Studie
study_sae = optuna.create_study(direction='maximize', pruner=optuna.pruners.MedianPruner())

def objective_sae(trial):
    # Hyperparameter-Suchraum
    latent_dim = trial.suggest_categorical('latent_dim', [2, 8, 16])
    activation = trial.suggest_categorical('activation', ['relu', 'mish', 'swish'])
    learning_rate = trial.suggest_float('learning_rate', 0.0001, 0.01, log=True)
    dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.2)
    l2_lambda = trial.suggest_float('l2_lambda', 0.001, 0.1, log=True)  # L2-Regularisierungsfaktor optimieren
    # Initialisiere ROC-AUC über die Folds
    roc_auc_scores = []

    # StratifiedKFold für robuste Evaluierung
    for train_idx, val_idx in skf.split(X_train, y_train.flatten()):
        X_train_fold = X_train[train_idx]
        y_train_fold = y_train[train_idx]
        X_val_fold = X_train[val_idx]
        y_val_fold = y_train[val_idx]

        # Erstelle und kompiliere das Modell
        model = create_model(model_class,latent_dim,
            classifier_dims=classifier_dims,  # Pass classifier_dims here
            activation=activation,
            dropout_rate=dropout_rate,
                             l2_lambda=l2_lambda)
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
        # Baue das Modell
        model.build(input_shape=(None, X_train_fold.shape[1]))
        history = model.fit(X_train_fold, y_train_fold, epochs=10, batch_size=64, validation_data=(X_val_fold, y_val_fold), verbose=0)

        # Berechne Klassifikations-ROC-AUC
        preds = (model.classify(model.encode(tf.convert_to_tensor(X_val_fold, dtype=tf.float32)))>0.5).numpy()
        roc_auc = roc_auc_score(y_val_fold.flatten(), preds)

        roc_auc_scores.append(roc_auc)

    # Rückgabe des durchschnittlichen ROC-AUC über alle Folds
    mean_roc_auc = np.mean(roc_auc_scores)
    return mean_roc_auc
# Führe 20 Trials durch
study_sae.optimize(objective_sae, n_trials=10)

# Speichere die besten Parameter
best_params = study_sae.best_params
best_params_dict[model_name] = best_params
print(f"Beste Parameter für {model_name}: {best_params}")
print(f"Bester durchschnittlicher ROC-AUC (5-Fold): {study_sae.best_value:.4f}")
# Out:
# [I 2025-03-03 10:43:01,515] A new study created in memory with name: no-name-ad4241e2-8514-4250-80b4-35be872973d6
# Starte Hyperparameter-Optimierung mit Optuna für SupervisedAE (ROC-AUC mit StratifiedKFold)...
# [I 2025-03-03 10:51:07,091] Trial 0 finished with value: 0.8806263428505032 and parameters: {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.00012432995218743362, 'dropout_rate': 0.11387567845644471, 'l2_lambda': 0.0012009532149099287}. Best is trial 0 with value: 0.8806263428505032.
# [I 2025-03-03 10:59:06,938] Trial 1 finished with value: 0.8021199854843551 and parameters: {'latent_dim': 8, 'activation': 'relu', 'learning_rate': 0.0057060419937430195, 'dropout_rate': 0.08385429518603082, 'l2_lambda': 0.03349993315665379}. Best is trial 0 with value: 0.8806263428505032.
# [I 2025-03-03 11:07:08,740] Trial 2 finished with value: 0.8425429736334419 and parameters: {'latent_dim': 2, 'activation': 'swish', 'learning_rate': 0.000109826501806088, 'dropout_rate': 0.19523312387055847, 'l2_lambda': 0.002811284966225735}. Best is trial 0 with value: 0.8806263428505032.
# [I 2025-03-03 11:15:05,469] Trial 3 finished with value: 0.8134816148428634 and parameters: {'latent_dim': 16, 'activation': 'relu', 'learning_rate': 0.0005063518834721688, 'dropout_rate': 0.19511452658948877, 'l2_lambda': 0.0037700392506412636}. Best is trial 0 with value: 0.8806263428505032.
# [I 2025-03-03 11:23:23,914] Trial 4 finished with value: 0.8793750675148525 and parameters: {'latent_dim': 2, 'activation': 'mish', 'learning_rate': 0.00010248724125511714, 'dropout_rate': 0.05143314661234791, 'l2_lambda': 0.006477490656103024}. Best is trial 0 with value: 0.8806263428505032.
# [I 2025-03-03 11:31:25,313] Trial 5 finished with value: 0.8299444225587805 and parameters: {'latent_dim': 8, 'activation': 'relu', 'learning_rate': 0.0016986224881571541, 'dropout_rate': 0.12945164105680698, 'l2_lambda': 0.005953566951439848}. Best is trial 0 with value: 0.8806263428505032.
# [I 2025-03-03 11:39:23,163] Trial 6 finished with value: 0.8477360927022881 and parameters: {'latent_dim': 2, 'activation': 'relu', 'learning_rate': 0.006206532994721784, 'dropout_rate': 0.0752713325717525, 'l2_lambda': 0.017088849923794978}. Best is trial 0 with value: 0.8806263428505032.
# [I 2025-03-03 11:47:24,838] Trial 7 finished with value: 0.8768420642080974 and parameters: {'latent_dim': 8, 'activation': 'swish', 'learning_rate': 0.0022172506947350733, 'dropout_rate': 0.05860051369034552, 'l2_lambda': 0.0014558632826589357}. Best is trial 0 with value: 0.8806263428505032.
# [I 2025-03-03 11:55:20,985] Trial 8 finished with value: 0.883177772939837 and parameters: {'latent_dim': 8, 'activation': 'relu', 'learning_rate': 0.0001221494559749793, 'dropout_rate': 0.0008899646616786994, 'l2_lambda': 0.056689827584544564}. Best is trial 8 with value: 0.883177772939837.
# [I 2025-03-03 12:03:20,542] Trial 9 finished with value: 0.8641807974298091 and parameters: {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.0026770952031640407, 'dropout_rate': 0.05035058244926578, 'l2_lambda': 0.008712541429279089}. Best is trial 8 with value: 0.883177772939837.
# Beste Parameter für SupervisedAE: {'latent_dim': 8, 'activation': 'relu', 'learning_rate': 0.0001221494559749793, 'dropout_rate': 0.0008899646616786994, 'l2_lambda': 0.056689827584544564}
# Bester durchschnittlicher ROC-AUC (5-Fold): 0.8832

# %%
# SAE
#axes[0, 0].set_title('SAE Hyperparameter Optimization')
optuna.visualization.matplotlib.plot_optimization_history(study_sae)
optuna.visualization.matplotlib.plot_param_importances(study_sae)
fig.show()
# Out:
# <ipython-input-122-349489dc8c06>:3: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_sae)
# <ipython-input-122-349489dc8c06>:4: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study_sae)

# %% [markdown]
# ## Optuna SVAE

# %%
classifier_dims = [16,8]
# Optimierung nur für SupervisedAE
model_class = SupervisedVAE
model_type = 'svae'
model_name = model_class.__name__
print(f"\nStarte Hyperparameter-Optimierung mit Optuna für {model_name} (ROC-AUC mit StratifiedKFold)...")

# Erstelle eine Optuna-Studie
study_svae = optuna.create_study(direction='maximize', pruner=optuna.pruners.MedianPruner())

def objective_svae(trial):
    # Hyperparameter-Suchraum
    latent_dim = trial.suggest_categorical('latent_dim', [2, 8, 16])
    activation = trial.suggest_categorical('activation', ['relu', 'mish', 'swish'])
    learning_rate = trial.suggest_float('learning_rate', 0.0001, 0.01, log=True)
    dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.2)
    l2_lambda = trial.suggest_float('l2_lambda', 0.001, 0.1, log=True)  # L2-Regularisierungsfaktor optimieren
    kl_weight = trial.suggest_float('kl_weight', 0.5, 2.0)  # KL-Verlust-Gewicht optimieren
    # Initialisiere ROC-AUC über die Folds
    roc_auc_scores = []

    # StratifiedKFold für robuste Evaluierung
    for train_idx, val_idx in skf.split(X_train, y_train.flatten()):
        X_train_fold = X_train[train_idx]
        y_train_fold = y_train[train_idx]
        X_val_fold = X_train[val_idx]
        y_val_fold = y_train[val_idx]

        # Erstelle und kompiliere das Modell
        model = create_model(model_class,
                             latent_dim=latent_dim,
                    classifier_dims=classifier_dim,
                         activation=activation,
    dropout_rate=dropout_rate,
    kl_weight=kl_weight,l2_lambda=l2_lambda)
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
        # Baue das Modell
        model.build(input_shape=(None, X_train_fold.shape[1]))
        history = model.fit(X_train_fold, y_train_fold, epochs=10, batch_size=64, validation_data=(X_val_fold, y_val_fold), verbose=0)

        # Berechne Klassifikations-ROC-AUC
        preds = model.predict(tf.convert_to_tensor(X_val_fold, dtype=tf.float32))[-1]>0.5
        roc_auc = roc_auc_score(y_val_fold.flatten(), preds)

        roc_auc_scores.append(roc_auc)

    # Rückgabe des durchschnittlichen ROC-AUC über alle Folds
    mean_roc_auc = np.mean(roc_auc_scores)
    return mean_roc_auc
# Führe 20 Trials durch
study_svae.optimize(objective_svae, n_trials=10)

# Speichere die besten Parameter
best_params = study_svae.best_params
best_params_dict[model_name] = best_params
print(f"Beste Parameter für {model_name}: {best_params}")
print(f"Bester durchschnittlicher ROC-AUC (5-Fold): {study_svae.best_value:.4f}")
# Out:
# [I 2025-03-03 12:20:20,314] A new study created in memory with name: no-name-a2a569a6-146d-4952-a58a-3514dd5bd6f3
# Starte Hyperparameter-Optimierung mit Optuna für SupervisedVAE (ROC-AUC mit StratifiedKFold)...
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 12:30:05,646] Trial 0 finished with value: 0.6208311192025193 and parameters: {'latent_dim': 8, 'activation': 'relu', 'learning_rate': 0.00014960699833325286, 'dropout_rate': 0.18973353309259766, 'l2_lambda': 0.05613984661527135, 'kl_weight': 1.6973420233580885}. Best is trial 0 with value: 0.6208311192025193.
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 12:39:48,783] Trial 1 finished with value: 0.8133776484718453 and parameters: {'latent_dim': 16, 'activation': 'swish', 'learning_rate': 0.003354365321129404, 'dropout_rate': 0.14982476992357896, 'l2_lambda': 0.058560570251322955, 'kl_weight': 1.9317734702634046}. Best is trial 1 with value: 0.8133776484718453.
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 12:49:15,825] Trial 2 finished with value: 0.582328847600787 and parameters: {'latent_dim': 16, 'activation': 'relu', 'learning_rate': 0.0001086310831872356, 'dropout_rate': 0.1836573062974121, 'l2_lambda': 0.0021516112616007587, 'kl_weight': 1.5562784988483296}. Best is trial 1 with value: 0.8133776484718453.
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 12:58:50,715] Trial 3 finished with value: 0.8692625154482752 and parameters: {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.0008813065559754224, 'dropout_rate': 0.08378198832618539, 'l2_lambda': 0.001801236112019939, 'kl_weight': 0.7085683277820094}. Best is trial 3 with value: 0.8692625154482752.
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 13:08:21,824] Trial 4 finished with value: 0.6931571348356743 and parameters: {'latent_dim': 8, 'activation': 'relu', 'learning_rate': 0.003208472289725845, 'dropout_rate': 0.10732922784275958, 'l2_lambda': 0.028225683454992413, 'kl_weight': 1.914592214153646}. Best is trial 3 with value: 0.8692625154482752.
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 13:17:56,210] Trial 5 finished with value: 0.5278217218417736 and parameters: {'latent_dim': 2, 'activation': 'mish', 'learning_rate': 0.004638217017639532, 'dropout_rate': 0.03587440010301488, 'l2_lambda': 0.0015272325677002402, 'kl_weight': 1.729509373606466}. Best is trial 3 with value: 0.8692625154482752.
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 13:27:53,582] Trial 6 finished with value: 0.7945816866187474 and parameters: {'latent_dim': 8, 'activation': 'mish', 'learning_rate': 0.00014111597896512468, 'dropout_rate': 0.030332674084738765, 'l2_lambda': 0.08922241060093687, 'kl_weight': 0.8745169092058025}. Best is trial 3 with value: 0.8692625154482752.
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 13:37:36,023] Trial 7 finished with value: 0.7781320683249134 and parameters: {'latent_dim': 8, 'activation': 'swish', 'learning_rate': 0.00044170860547099015, 'dropout_rate': 0.17887994976529425, 'l2_lambda': 0.013283397444414806, 'kl_weight': 0.679004609103674}. Best is trial 3 with value: 0.8692625154482752.
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 13:47:14,464] Trial 8 finished with value: 0.8616268458891616 and parameters: {'latent_dim': 8, 'activation': 'swish', 'learning_rate': 0.0009232876550833787, 'dropout_rate': 0.1182945093674164, 'l2_lambda': 0.006031813463843398, 'kl_weight': 1.591485595930365}. Best is trial 3 with value: 0.8692625154482752.
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# 1425/1425 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# [I 2025-03-03 13:56:52,452] Trial 9 finished with value: 0.6011976759393496 and parameters: {'latent_dim': 8, 'activation': 'swish', 'learning_rate': 0.005179061303311855, 'dropout_rate': 0.10038512416156387, 'l2_lambda': 0.0010582081810385357, 'kl_weight': 1.27044515184219}. Best is trial 3 with value: 0.8692625154482752.
# Beste Parameter für SupervisedVAE: {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.0008813065559754224, 'dropout_rate': 0.08378198832618539, 'l2_lambda': 0.001801236112019939, 'kl_weight': 0.7085683277820094}
# Bester durchschnittlicher ROC-AUC (5-Fold): 0.8693

# %% [markdown]
# ## Ergebnisse Visualiseren

# %%
 #SAE

#axes[0, 0].set_title('SAE Hyperparameter Optimization')
optuna.visualization.matplotlib.plot_optimization_history(study_svae)
optuna.visualization.matplotlib.plot_param_importances(study_svae)
fig.show()
# Out:
# <ipython-input-124-c954ea7ae00b>:4: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study_svae)
# <ipython-input-124-c954ea7ae00b>:5: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study_svae)

# %%
# !pip install -U optuna
import matplotlib.pyplot as plt
import numpy as np
import optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.14.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.38)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (1.3.9)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
# Definiere models korrekt als Liste von (study, title) Tupeln
models = [
    (study_uae, "UAE"),
    (study_uvae, "UVAE"),
    (study_sae, "SAE"),
    (study_svae, "SVAE")
]

# Parameterwichtigkeit plotten
fig_import, axes_import = plt.subplots(2, 2, figsize=(15, 10))
axes_import = axes_import.flatten()

for idx, (study, title) in enumerate(models):
    if study is not None and len(study.trials) > 0:
        ax = axes_import[idx]

        try:
            # Parameterwichtigkeit berechnen
            importance_values = optuna.importance.get_param_importances(study)

            if importance_values:
                # Sortieren für bessere Lesbarkeit
                sorted_importances = sorted(importance_values.items(), key=lambda x: x[1], reverse=True)
                param_names = [name for name, _ in sorted_importances]
                importance_scores = [value for _, value in sorted_importances]

                # Parameter auf maximal 10 beschränken, falls zu viele vorhanden sind
                if len(param_names) > 10:
                    param_names = param_names[:10]
                    importance_scores = importance_scores[:10]

                # Farbpalette erstellen
                colors = plt.cm.viridis(np.linspace(0.2, 0.8, len(param_names)))

                # Horizontaler Barplot für bessere Lesbarkeit bei langen Parameternamen
                bars = ax.barh(range(len(param_names)), importance_scores, color=colors)
                ax.set_yticks(range(len(param_names)))
                ax.set_yticklabels(param_names)

                # Werte an Balkenenden anzeigen
                for i, v in enumerate(importance_scores):
                    ax.text(v + 0.01, i, f'{v:.3f}', va='center')

                ax.set_title(f'{title} - Parameterwichtigkeit')
                ax.set_xlabel('Wichtigkeit')
                ax.set_ylabel('Hyperparameter')
                ax.grid(True, alpha=0.3, axis='x')
                ax.set_xlim(0, max(importance_scores) * 1.1)  # Platz für die Wertbeschriftungen
            else:
                ax.text(0.5, 0.5, 'Keine Parameterwichtigkeiten verfügbar', ha='center', va='center')
        except Exception as e:
            ax.text(0.5, 0.5, f'Fehler: {str(e)}', ha='center', va='center')
            print(f"Fehler bei {title}: {e}")
    else:
        axes_import[idx].text(0.5, 0.5, 'Keine Daten verfügbar', ha='center', va='center')

plt.tight_layout()
import_path = os.path.join(save_dir, 'hyperparameter_importance.png')
plt.savefig(import_path, dpi=300, bbox_inches='tight')
plt.show()
plt.close(fig_import)

print(f"Visualisierungen wurden gespeichert unter: {save_dir}")
# Out:
# Visualisierungen wurden gespeichert unter: /content/drive/MyDrive/models

# %%
display(best_params_dict)
# Out:
# {'UnsupervisedAE': {'latent_dim': 2,
#   'activation': 'swish',
#   'learning_rate': 0.0036884550320333475,
#   'dropout_rate': 0.14438827330883364},
#  'UnsupervisedVAE': {'latent_dim': 2,
#   'activation': 'swish',
#   'learning_rate': 0.00022252325857421317,
#   'dropout_rate': 0.07061057411978693,
#   'kl_weight': 1.2003344773811349},
#  'SupervisedAE': {'latent_dim': 8,
#   'activation': 'relu',
#   'learning_rate': 0.0001221494559749793,
#   'dropout_rate': 0.0008899646616786994,
#   'l2_lambda': 0.056689827584544564},
#  'SupervisedVAE': {'latent_dim': 16,
#   'activation': 'mish',
#   'learning_rate': 0.0008813065559754224,
#   'dropout_rate': 0.08378198832618539,
#   'l2_lambda': 0.001801236112019939,
#   'kl_weight': 0.7085683277820094}}

# %%
import pickle
import os

# %%
# Zielpfad für die Speicherung
save_dir = '/content/drive/MyDrive/best_ordner'  # Passe den Pfad an
os.makedirs(save_dir, exist_ok=True)

# %%
json_path = os.path.join(save_dir, 'best_hyperparams.json')
with open(json_path, 'w') as f:
    json.dump(best_params_dict, f, indent=4)

print(f"Hyperparameter erfolgreich gespeichert unter: {json_path}")
# Out:
# Hyperparameter erfolgreich gespeichert unter: /content/drive/MyDrive/best_ordner/best_hyperparams.json

# %% [markdown]
# # VII. Modelle mit bestparameter durchführen

# %% [markdown]
# ## 1. UAE

# %% [markdown]
# Beste Parameter aus Github laden

# %%
import requests
import json

# Download the file using requests
json_url = "https://raw.githubusercontent.com/mylibui/demo/refs/heads/master/best_hyperparams_best_2.json"
response = requests.get(json_url)
response.raise_for_status()  # Raise an exception for bad responses

# Load the JSON data
try:
    data_dict = json.loads(response.text)
    print("Type der geladenen Daten:", type(data_dict))
except json.JSONDecodeError as e:
    print(f"Fehler beim Laden der JSON-Datei: {e}")
# Out:
# Type der geladenen Daten: <class 'dict'>

# %%
data_dict
# Out:
# {'UnsupervisedAE': {'latent_dim': 2,
#   'activation': 'swish',
#   'learning_rate': 0.0036884550320333475,
#   'dropout_rate': 0.14438827330883364},
#  'UnsupervisedVAE': {'latent_dim': 2,
#   'activation': 'swish',
#   'learning_rate': 0.00022252325857421317,
#   'dropout_rate': 0.07061057411978693,
#   'kl_weight': 1.2003344773811349},
#  'SupervisedAE': {'latent_dim': 8,
#   'activation': 'relu',
#   'learning_rate': 0.0001221494559749793,
#   'dropout_rate': 0.0008899646616786994,
#   'l2_lambda': 0.056689827584544564},
#  'SupervisedVAE': {'latent_dim': 16,
#   'activation': 'mish',
#   'learning_rate': 0.0008813065559754224,
#   'dropout_rate': 0.08378198832618539,
#   'l2_lambda': 0.001801236112019939,
#   'kl_weight': 0.7085683277820094}}

# %%
data_dict.items()
# Out:
# dict_items([('UnsupervisedAE', {'latent_dim': 2, 'activation': 'swish', 'learning_rate': 0.0036884550320333475, 'dropout_rate': 0.14438827330883364}), ('UnsupervisedVAE', {'latent_dim': 2, 'activation': 'swish', 'learning_rate': 0.00022252325857421317, 'dropout_rate': 0.07061057411978693, 'kl_weight': 1.2003344773811349}), ('SupervisedAE', {'latent_dim': 8, 'activation': 'relu', 'learning_rate': 0.0001221494559749793, 'dropout_rate': 0.0008899646616786994, 'l2_lambda': 0.056689827584544564}), ('SupervisedVAE', {'latent_dim': 16, 'activation': 'mish', 'learning_rate': 0.0008813065559754224, 'dropout_rate': 0.08378198832618539, 'l2_lambda': 0.001801236112019939, 'kl_weight': 0.7085683277820094})])

# %%
# Initialisiere ein Dictionary für die trainierten Modelle
trained_models = {}

model_classes = {
    'UnsupervisedAE': UnsupervisedAE,
    'UnsupervisedVAE': UnsupervisedVAE,
    'SupervisedAE': SupervisedAE,
    'SupervisedVAE': SupervisedVAE
}

for model_name, config in data_dict.items():
    # Extrahiere Modellparameter
    latent_dim = config['latent_dim']
    activation = config['activation']
    dropout_rate = config['dropout_rate']
    learning_rate = config['learning_rate']

    # Zusätzliche Parameter
    kl_weight = config.get('kl_weight')
    l2_lambda = config.get('l2_lambda')

    # Erstelle das Modell
    model = create_model(
        model_class=model_classes[model_name],
        latent_dim=latent_dim,
        activation=activation,
        dropout_rate=dropout_rate,
        kl_weight=kl_weight,
        l2_lambda=l2_lambda,
        classifier_dims=[16,8]
    )

    # Kompiliere das Modell
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

    trained_models[model_name] = model

print("Erfolgreich erstellte Modelle:", list(trained_models.keys()))
# Out:
# Erfolgreich erstellte Modelle: ['UnsupervisedAE', 'UnsupervisedVAE', 'SupervisedAE', 'SupervisedVAE']

# %%
# Erstellen und Trainieren des Autoencoders mit anpassbaren Parametern
best_uae = UnsupervisedAE(
    input_dim=X_train_normal.shape[1],
    hidden_dims=[64, 32],  # Standardmäßig [64, 32], aber anpassbar
    latent_dim=data_dict['UnsupervisedAE']["latent_dim"],  # Anpassbar
    activation=data_dict['UnsupervisedAE']["activation"],  # Anpassbar
    dropout_rate=data_dict['UnsupervisedAE']["dropout_rate"]  # Anpassbar
)
best_uae.build(input_shape=(None, X_train.shape[1]))
# Konfigurieren des Optimierers
best_uae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=data_dict['UnsupervisedAE']["learning_rate"]))

# Training des Autoencoders
history_best_uae = best_uae.fit(
    X_train_normal,
    epochs=100,
    batch_size=batch_size,
    validation_split=0.1,
    verbose=0,callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_total_loss` which is not available. Available metrics are: reconstruction_loss,val_reconstruction_loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_total_loss` which is not available. Available metrics are: reconstruction_loss,val_reconstruction_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)

# %%
beste_threshold,_ = find_optimal_threshold(best_uae, X_test, y_test)
print(f"Optimaler Schwellenwert: {beste_threshold}")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.716206288337707
# Optimaler Schwellenwert: 1.716206288337707

# %%
# Visualisierung und Speichern in Google Drive mit Markierung von Fraud vs. Nicht Fraud
plot_reconstruction_analysis(
    best_uae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="best_ae_results",
    threshold=beste_threshold  # Verwende den optimalen Schwellenwert
)
# Out:
# <ipython-input-13-198ed5571b77>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=labels, y=data, palette={'Nicht Fraud': 'blue', 'Fraud': 'red'})
# Analyse wurde gespeichert unter: /content/drive/MyDrive/best_ae_results/reconstruction_analysis_20250309_093900.png

# %%
fig, axes = plot_loss_curves(
    history_best_uae,
    model_type='uae',
    folder_name="best_ae_results"
)
# Out:
# Warnung: 'loss' nicht in history.history gefunden – Gesamtverlust wird nicht geplottet.
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/best_ae_results/loss_curves_uae.png

# %%
plot_roc_auc_curve(
    best_uae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="best_ae_results")
plot_pr_curve(
    best_uae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="best_ae_results")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.724358129501341
# Optimaler Schwellenwert basierend auf F1-Score: 1.724358129501341
# ROC-Kurve wurde gespeichert unter: /content/drive/MyDrive/best_ae_results/UnsupervisedAEroc_curve_20250309_093903.png
# ROC-AUC: 0.9617
# Precision-Recall-Kurve wurde gespeichert unter: /content/drive/MyDrive/best_ae_results/pr_curve_20250309_093903.png

# %%
X_predict=best_uae.predict(X_test)
mse=np.mean(np.power(X_test-X_predict,2),axis=1)
fpr, tpr, _ = roc_curve(y_test, mse)
roc_auc = auc(fpr, tpr)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step

# %%
fraud_predictions = detect_fraud(best_uae, X_test)
plot_confusion_matrix(model="Unsupervised AE", y_true=y_test, y_pred=fraud_predictions,folder_name="best_ae_results")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.714889067411419
# Optimaler Schwellenwert (ohne echte Labels): 1.714889067411419

# %%
print(f"Bestes ROC-AUC: {roc_auc}")
# Out:
# Bestes ROC-AUC: 0.9617366677959872

# %% [markdown]
# ## VAE

# %%
# Erstellen und Trainieren des Autoencoders mit anpassbaren Parametern
best_vae = UnsupervisedVAE(
    input_dim=X_train_normal.shape[1],
    hidden_dims=[64, 32],  # Standardmäßig [64, 32], aber anpassbar
    latent_dim=data_dict['UnsupervisedVAE']["latent_dim"],  # Anpassbar
    activation=data_dict['UnsupervisedVAE']["activation"],  # Anpassbar
    dropout_rate=data_dict['UnsupervisedVAE']["dropout_rate"],
    kl_weight=data_dict['UnsupervisedVAE']["kl_weight"]# Anpassbar
)
best_vae.build(input_shape=(None, X_train.shape[1]))
# Konfigurieren des Optimierers
best_vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=data_dict['UnsupervisedVAE']["learning_rate"]))

# Training des Autoencoders
history_best_uvae = best_vae.fit(
    X_train_normal,
    epochs=50,
    batch_size=batch_size,
    validation_split=0.1,
    verbose=1,callbacks=callbacks
)
# Out:
# Epoch 1/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - kl_loss: 2.5452 - loss: 33.8333 - reconstruction_loss: 30.7782 - val_kl_loss: 0.2083 - val_reconstruction_loss: 28.0278 - val_total_loss: 28.2778 - learning_rate: 2.2252e-04
# Epoch 2/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 6.6906 - loss: 40.5790 - reconstruction_loss: 32.5480 - val_kl_loss: 0.3057 - val_reconstruction_loss: 27.6454 - val_total_loss: 28.0123 - learning_rate: 2.2252e-04
# Epoch 3/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 0.3202 - loss: 28.4570 - reconstruction_loss: 28.0727 - val_kl_loss: 0.5641 - val_reconstruction_loss: 26.6302 - val_total_loss: 27.3073 - learning_rate: 2.2252e-04
# Epoch 4/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 0.5641 - loss: 27.8842 - reconstruction_loss: 27.2071 - val_kl_loss: 0.7909 - val_reconstruction_loss: 25.8568 - val_total_loss: 26.8061 - learning_rate: 2.2252e-04
# Epoch 5/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 0.9102 - loss: 28.7592 - reconstruction_loss: 27.6667 - val_kl_loss: 0.8609 - val_reconstruction_loss: 25.5021 - val_total_loss: 26.5355 - learning_rate: 2.2252e-04
# Epoch 6/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 0.8627 - loss: 27.2634 - reconstruction_loss: 26.2278 - val_kl_loss: 0.9909 - val_reconstruction_loss: 25.1097 - val_total_loss: 26.2992 - learning_rate: 2.2252e-04
# Epoch 7/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 0.9821 - loss: 26.9425 - reconstruction_loss: 25.7637 - val_kl_loss: 1.1085 - val_reconstruction_loss: 24.6276 - val_total_loss: 25.9582 - learning_rate: 2.2252e-04
# Epoch 8/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.0894 - loss: 26.6168 - reconstruction_loss: 25.3092 - val_kl_loss: 1.1306 - val_reconstruction_loss: 24.3102 - val_total_loss: 25.6673 - learning_rate: 2.2252e-04
# Epoch 9/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.1669 - loss: 26.3417 - reconstruction_loss: 24.9410 - val_kl_loss: 1.1988 - val_reconstruction_loss: 24.0314 - val_total_loss: 25.4704 - learning_rate: 2.2252e-04
# Epoch 10/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.2203 - loss: 26.1259 - reconstruction_loss: 24.6611 - val_kl_loss: 1.2609 - val_reconstruction_loss: 23.7636 - val_total_loss: 25.2771 - learning_rate: 2.2252e-04
# Epoch 11/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.2535 - loss: 25.9509 - reconstruction_loss: 24.4463 - val_kl_loss: 1.2853 - val_reconstruction_loss: 23.6653 - val_total_loss: 25.2081 - learning_rate: 2.2252e-04
# Epoch 12/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.2781 - loss: 25.8435 - reconstruction_loss: 24.3095 - val_kl_loss: 1.2872 - val_reconstruction_loss: 23.5711 - val_total_loss: 25.1162 - learning_rate: 2.2252e-04
# Epoch 13/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.2986 - loss: 25.7042 - reconstruction_loss: 24.1453 - val_kl_loss: 1.2815 - val_reconstruction_loss: 23.4579 - val_total_loss: 24.9962 - learning_rate: 2.2252e-04
# Epoch 14/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.3248 - loss: 25.5816 - reconstruction_loss: 23.9914 - val_kl_loss: 1.3556 - val_reconstruction_loss: 23.3111 - val_total_loss: 24.9383 - learning_rate: 2.2252e-04
# Epoch 15/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.3395 - loss: 25.4576 - reconstruction_loss: 23.8497 - val_kl_loss: 1.3602 - val_reconstruction_loss: 23.2974 - val_total_loss: 24.9301 - learning_rate: 2.2252e-04
# Epoch 16/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.3745 - loss: 25.3851 - reconstruction_loss: 23.7353 - val_kl_loss: 1.3619 - val_reconstruction_loss: 23.1638 - val_total_loss: 24.7985 - learning_rate: 2.2252e-04
# Epoch 17/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.3856 - loss: 25.2376 - reconstruction_loss: 23.5744 - val_kl_loss: 1.3547 - val_reconstruction_loss: 23.2187 - val_total_loss: 24.8448 - learning_rate: 2.2252e-04
# Epoch 18/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.3886 - loss: 25.1608 - reconstruction_loss: 23.4940 - val_kl_loss: 1.3650 - val_reconstruction_loss: 23.0373 - val_total_loss: 24.6758 - learning_rate: 2.2252e-04
# Epoch 19/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.4081 - loss: 25.1217 - reconstruction_loss: 23.4316 - val_kl_loss: 1.4251 - val_reconstruction_loss: 22.9557 - val_total_loss: 24.6663 - learning_rate: 2.2252e-04
# Epoch 20/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.4367 - loss: 25.0369 - reconstruction_loss: 23.3124 - val_kl_loss: 1.4242 - val_reconstruction_loss: 22.8539 - val_total_loss: 24.5634 - learning_rate: 2.2252e-04
# Epoch 21/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.4499 - loss: 24.8766 - reconstruction_loss: 23.1362 - val_kl_loss: 1.4689 - val_reconstruction_loss: 22.6540 - val_total_loss: 24.4172 - learning_rate: 2.2252e-04
# Epoch 22/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.4806 - loss: 24.7706 - reconstruction_loss: 22.9933 - val_kl_loss: 1.4704 - val_reconstruction_loss: 22.5707 - val_total_loss: 24.3358 - learning_rate: 2.2252e-04
# Epoch 23/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.5100 - loss: 24.6390 - reconstruction_loss: 22.8265 - val_kl_loss: 1.5215 - val_reconstruction_loss: 22.4528 - val_total_loss: 24.2792 - learning_rate: 2.2252e-04
# Epoch 24/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.5461 - loss: 24.4968 - reconstruction_loss: 22.6409 - val_kl_loss: 1.5388 - val_reconstruction_loss: 22.3237 - val_total_loss: 24.1707 - learning_rate: 2.2252e-04
# Epoch 25/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.5659 - loss: 24.3391 - reconstruction_loss: 22.4595 - val_kl_loss: 1.5397 - val_reconstruction_loss: 22.2122 - val_total_loss: 24.0604 - learning_rate: 2.2252e-04
# Epoch 26/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.5652 - loss: 24.2700 - reconstruction_loss: 22.3913 - val_kl_loss: 1.5646 - val_reconstruction_loss: 22.2096 - val_total_loss: 24.0876 - learning_rate: 2.2252e-04
# Epoch 27/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.5831 - loss: 24.1470 - reconstruction_loss: 22.2467 - val_kl_loss: 1.5639 - val_reconstruction_loss: 22.0685 - val_total_loss: 23.9457 - learning_rate: 2.2252e-04
# Epoch 28/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.5880 - loss: 24.0932 - reconstruction_loss: 22.1871 - val_kl_loss: 1.5573 - val_reconstruction_loss: 22.0500 - val_total_loss: 23.9193 - learning_rate: 2.2252e-04
# Epoch 29/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6083 - loss: 23.9502 - reconstruction_loss: 22.0198 - val_kl_loss: 1.5885 - val_reconstruction_loss: 21.8539 - val_total_loss: 23.7606 - learning_rate: 2.2252e-04
# Epoch 30/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6072 - loss: 23.9733 - reconstruction_loss: 22.0441 - val_kl_loss: 1.6149 - val_reconstruction_loss: 21.8228 - val_total_loss: 23.7613 - learning_rate: 2.2252e-04
# Epoch 31/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6324 - loss: 23.8509 - reconstruction_loss: 21.8914 - val_kl_loss: 1.6086 - val_reconstruction_loss: 21.7804 - val_total_loss: 23.7112 - learning_rate: 2.2252e-04
# Epoch 32/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6208 - loss: 23.7922 - reconstruction_loss: 21.8467 - val_kl_loss: 1.6195 - val_reconstruction_loss: 21.7682 - val_total_loss: 23.7122 - learning_rate: 2.2252e-04
# Epoch 33/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6235 - loss: 23.7679 - reconstruction_loss: 21.8191 - val_kl_loss: 1.6160 - val_reconstruction_loss: 21.7152 - val_total_loss: 23.6549 - learning_rate: 2.2252e-04
# Epoch 34/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6404 - loss: 23.7006 - reconstruction_loss: 21.7315 - val_kl_loss: 1.6210 - val_reconstruction_loss: 21.6434 - val_total_loss: 23.5891 - learning_rate: 2.2252e-04
# Epoch 35/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6525 - loss: 23.7048 - reconstruction_loss: 21.7213 - val_kl_loss: 1.6305 - val_reconstruction_loss: 21.6930 - val_total_loss: 23.6502 - learning_rate: 2.2252e-04
# Epoch 36/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6588 - loss: 23.6389 - reconstruction_loss: 21.6478 - val_kl_loss: 1.6275 - val_reconstruction_loss: 21.6060 - val_total_loss: 23.5595 - learning_rate: 2.2252e-04
# Epoch 37/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6633 - loss: 23.5707 - reconstruction_loss: 21.5742 - val_kl_loss: 1.6344 - val_reconstruction_loss: 21.6026 - val_total_loss: 23.5644 - learning_rate: 2.2252e-04
# Epoch 38/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.6795 - loss: 23.5847 - reconstruction_loss: 21.5687 - val_kl_loss: 1.6791 - val_reconstruction_loss: 21.4365 - val_total_loss: 23.4520 - learning_rate: 2.2252e-04
# Epoch 39/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.7094 - loss: 23.5201 - reconstruction_loss: 21.4683 - val_kl_loss: 1.7148 - val_reconstruction_loss: 21.2966 - val_total_loss: 23.3550 - learning_rate: 2.2252e-04
# Epoch 40/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.7502 - loss: 23.4849 - reconstruction_loss: 21.3840 - val_kl_loss: 1.7851 - val_reconstruction_loss: 21.1971 - val_total_loss: 23.3399 - learning_rate: 2.2252e-04
# Epoch 41/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.7999 - loss: 23.3606 - reconstruction_loss: 21.2002 - val_kl_loss: 1.8162 - val_reconstruction_loss: 21.0768 - val_total_loss: 23.2569 - learning_rate: 2.2252e-04
# Epoch 42/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.8365 - loss: 23.2864 - reconstruction_loss: 21.0819 - val_kl_loss: 1.8167 - val_reconstruction_loss: 21.0722 - val_total_loss: 23.2528 - learning_rate: 2.2252e-04
# Epoch 43/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.8482 - loss: 23.2213 - reconstruction_loss: 21.0029 - val_kl_loss: 1.8348 - val_reconstruction_loss: 20.9979 - val_total_loss: 23.2002 - learning_rate: 2.2252e-04
# Epoch 44/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.8605 - loss: 23.1810 - reconstruction_loss: 20.9477 - val_kl_loss: 1.8242 - val_reconstruction_loss: 20.8404 - val_total_loss: 23.0300 - learning_rate: 2.2252e-04
# Epoch 45/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.8629 - loss: 23.1652 - reconstruction_loss: 20.9291 - val_kl_loss: 1.8574 - val_reconstruction_loss: 20.8079 - val_total_loss: 23.0375 - learning_rate: 2.2252e-04
# Epoch 46/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.8836 - loss: 23.1023 - reconstruction_loss: 20.8414 - val_kl_loss: 1.8452 - val_reconstruction_loss: 20.9287 - val_total_loss: 23.1436 - learning_rate: 2.2252e-04
# Epoch 47/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.8880 - loss: 23.1102 - reconstruction_loss: 20.8439 - val_kl_loss: 1.8809 - val_reconstruction_loss: 20.7254 - val_total_loss: 22.9832 - learning_rate: 2.2252e-04
# Epoch 48/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.8965 - loss: 23.0417 - reconstruction_loss: 20.7653 - val_kl_loss: 1.9095 - val_reconstruction_loss: 20.6987 - val_total_loss: 22.9907 - learning_rate: 2.2252e-04
# Epoch 49/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.9085 - loss: 23.0196 - reconstruction_loss: 20.7287 - val_kl_loss: 1.8721 - val_reconstruction_loss: 20.7875 - val_total_loss: 23.0347 - learning_rate: 2.2252e-04
# Epoch 50/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - kl_loss: 1.9100 - loss: 22.9676 - reconstruction_loss: 20.6749 - val_kl_loss: 1.8969 - val_reconstruction_loss: 20.6336 - val_total_loss: 22.9105 - learning_rate: 2.2252e-04

# %%
# Visualisierung und Speichern in Google Drive mit Markierung von Fraud vs. Nicht Fraud
plot_reconstruction_analysis(
    best_vae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="best_vae_results" # Verwende den optimalen Schwellenwert
)
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.432835459709167
# <ipython-input-13-198ed5571b77>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=labels, y=data, palette={'Nicht Fraud': 'blue', 'Fraud': 'red'})
# Analyse wurde gespeichert unter: /content/drive/MyDrive/best_vae_results/reconstruction_analysis_20250309_094108.png

# %%
plot_roc_auc_curve(
    best_vae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="best_vae_results")
plot_pr_curve(
    best_vae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="best_vae_results")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.4420248866081236
# Optimaler Schwellenwert basierend auf F1-Score: 1.4420248866081236
# ROC-Kurve wurde gespeichert unter: /content/drive/MyDrive/best_vae_results/UnsupervisedVAEroc_curve_20250309_094110.png
# ROC-AUC: 0.9616
# Precision-Recall-Kurve wurde gespeichert unter: /content/drive/MyDrive/best_vae_results/pr_curve_20250309_094110.png

# %%
fraud_predictions = detect_fraud(best_vae, X_test)
plot_confusion_matrix(model="Unsupervised VAE", y_true=y_test, y_pred=fraud_predictions,folder_name="best_vae_results")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.4416344285011289
# Optimaler Schwellenwert (ohne echte Labels): 1.4416344285011289

# %% [markdown]
# ##SAE

# %%
# Erstellen und Trainieren des Autoencoders mit anpassbaren Parametern
best_suae = SupervisedAE(
    input_dim=X_train_normal.shape[1],
    latent_dim=data_dict['SupervisedAE']["latent_dim"],  # Anpassbar
    activation=data_dict['SupervisedAE']["activation"],  # Anpassbar
    dropout_rate=data_dict['SupervisedAE']["dropout_rate"],  # Anpassbar,
    classifier_dims=[16,8],
    l2_lambda=data_dict['SupervisedAE']["l2_lambda"]
)

best_suae.build(input_shape=(None, X_train.shape[1]))
# Konfigurieren des Optimierers
best_suae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=data_dict['SupervisedAE']["learning_rate"]))

# Training des Autoencoders
history_best_suae = best_suae.fit(
    X_train,y_train,
    epochs=100,
    batch_size=batch_size,
    validation_split=0.1,
    verbose=1,callbacks=callbacks
)
# Out:
# Epoch 1/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - classification_loss: 0.3139 - reconstruction_loss: 29.0328 - total_loss: 1.9598 - val_classification_loss: 0.0403 - val_reconstruction_loss: 21.3594 - val_total_loss: 1.2507 - learning_rate: 1.2215e-04
# Epoch 2/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0296 - reconstruction_loss: 21.1520 - total_loss: 1.2287 - val_classification_loss: 0.0184 - val_reconstruction_loss: 18.1809 - val_total_loss: 1.0489 - learning_rate: 1.2215e-04
# Epoch 3/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0125 - reconstruction_loss: 18.3071 - total_loss: 1.0503 - val_classification_loss: 0.0048 - val_reconstruction_loss: 16.3030 - val_total_loss: 0.9290 - learning_rate: 1.2215e-04
# Epoch 4/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0061 - reconstruction_loss: 16.4823 - total_loss: 0.9405 - val_classification_loss: 0.0046 - val_reconstruction_loss: 15.0152 - val_total_loss: 0.8558 - learning_rate: 1.2215e-04
# Epoch 5/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0056 - reconstruction_loss: 15.1985 - total_loss: 0.8672 - val_classification_loss: 0.0049 - val_reconstruction_loss: 14.0029 - val_total_loss: 0.7986 - learning_rate: 1.2215e-04
# Epoch 6/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0054 - reconstruction_loss: 14.1424 - total_loss: 0.8071 - val_classification_loss: 0.0048 - val_reconstruction_loss: 13.2098 - val_total_loss: 0.7537 - learning_rate: 1.2215e-04
# Epoch 7/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0052 - reconstruction_loss: 13.3849 - total_loss: 0.7640 - val_classification_loss: 0.0052 - val_reconstruction_loss: 12.6468 - val_total_loss: 0.7221 - learning_rate: 1.2215e-04
# Epoch 8/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0049 - reconstruction_loss: 12.7487 - total_loss: 0.7276 - val_classification_loss: 0.0049 - val_reconstruction_loss: 12.1168 - val_total_loss: 0.6917 - learning_rate: 1.2215e-04
# Epoch 9/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0051 - reconstruction_loss: 12.1887 - total_loss: 0.6960 - val_classification_loss: 0.0047 - val_reconstruction_loss: 11.6799 - val_total_loss: 0.6668 - learning_rate: 1.2215e-04
# Epoch 10/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0047 - reconstruction_loss: 11.7300 - total_loss: 0.6697 - val_classification_loss: 0.0046 - val_reconstruction_loss: 11.2930 - val_total_loss: 0.6448 - learning_rate: 1.2215e-04
# Epoch 11/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0045 - reconstruction_loss: 11.2949 - total_loss: 0.6448 - val_classification_loss: 0.0045 - val_reconstruction_loss: 10.9116 - val_total_loss: 0.6230 - learning_rate: 1.2215e-04
# Epoch 12/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0045 - reconstruction_loss: 10.9295 - total_loss: 0.6241 - val_classification_loss: 0.0045 - val_reconstruction_loss: 10.5961 - val_total_loss: 0.6051 - learning_rate: 1.2215e-04
# Epoch 13/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0047 - reconstruction_loss: 10.6354 - total_loss: 0.6076 - val_classification_loss: 0.0044 - val_reconstruction_loss: 10.3261 - val_total_loss: 0.5898 - learning_rate: 1.2215e-04
# Epoch 14/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0044 - reconstruction_loss: 10.3406 - total_loss: 0.5906 - val_classification_loss: 0.0043 - val_reconstruction_loss: 10.0945 - val_total_loss: 0.5765 - learning_rate: 1.2215e-04
# Epoch 15/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0044 - reconstruction_loss: 10.1117 - total_loss: 0.5776 - val_classification_loss: 0.0042 - val_reconstruction_loss: 9.8514 - val_total_loss: 0.5626 - learning_rate: 1.2215e-04
# Epoch 16/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0042 - reconstruction_loss: 9.9251 - total_loss: 0.5669 - val_classification_loss: 0.0042 - val_reconstruction_loss: 9.6413 - val_total_loss: 0.5507 - learning_rate: 1.2215e-04
# Epoch 17/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0042 - reconstruction_loss: 9.6669 - total_loss: 0.5522 - val_classification_loss: 0.0041 - val_reconstruction_loss: 9.4736 - val_total_loss: 0.5411 - learning_rate: 1.2215e-04
# Epoch 18/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0041 - reconstruction_loss: 9.4883 - total_loss: 0.5420 - val_classification_loss: 0.0041 - val_reconstruction_loss: 9.2760 - val_total_loss: 0.5299 - learning_rate: 1.2215e-04
# Epoch 19/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0040 - reconstruction_loss: 9.3081 - total_loss: 0.5317 - val_classification_loss: 0.0041 - val_reconstruction_loss: 9.1599 - val_total_loss: 0.5233 - learning_rate: 1.2215e-04
# Epoch 20/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0040 - reconstruction_loss: 9.1502 - total_loss: 0.5227 - val_classification_loss: 0.0040 - val_reconstruction_loss: 8.9658 - val_total_loss: 0.5122 - learning_rate: 1.2215e-04
# Epoch 21/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0040 - reconstruction_loss: 8.9529 - total_loss: 0.5115 - val_classification_loss: 0.0040 - val_reconstruction_loss: 8.8213 - val_total_loss: 0.5040 - learning_rate: 1.2215e-04
# Epoch 22/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0040 - reconstruction_loss: 8.7935 - total_loss: 0.5025 - val_classification_loss: 0.0042 - val_reconstruction_loss: 8.6850 - val_total_loss: 0.4965 - learning_rate: 1.2215e-04
# Epoch 23/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0039 - reconstruction_loss: 8.6468 - total_loss: 0.4941 - val_classification_loss: 0.0039 - val_reconstruction_loss: 8.5613 - val_total_loss: 0.4892 - learning_rate: 1.2215e-04
# Epoch 24/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0042 - reconstruction_loss: 8.5188 - total_loss: 0.4871 - val_classification_loss: 0.0039 - val_reconstruction_loss: 8.4303 - val_total_loss: 0.4818 - learning_rate: 1.2215e-04
# Epoch 25/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0038 - reconstruction_loss: 8.4470 - total_loss: 0.4827 - val_classification_loss: 0.0039 - val_reconstruction_loss: 8.3727 - val_total_loss: 0.4785 - learning_rate: 1.2215e-04
# Epoch 26/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0038 - reconstruction_loss: 8.3044 - total_loss: 0.4745 - val_classification_loss: 0.0038 - val_reconstruction_loss: 8.2313 - val_total_loss: 0.4704 - learning_rate: 1.2215e-04
# Epoch 27/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0038 - reconstruction_loss: 8.1768 - total_loss: 0.4673 - val_classification_loss: 0.0038 - val_reconstruction_loss: 8.1628 - val_total_loss: 0.4665 - learning_rate: 1.2215e-04
# Epoch 28/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0038 - reconstruction_loss: 8.0910 - total_loss: 0.4625 - val_classification_loss: 0.0038 - val_reconstruction_loss: 8.0784 - val_total_loss: 0.4617 - learning_rate: 1.2215e-04
# Epoch 29/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0037 - reconstruction_loss: 8.0048 - total_loss: 0.4575 - val_classification_loss: 0.0037 - val_reconstruction_loss: 8.0932 - val_total_loss: 0.4625 - learning_rate: 1.2215e-04
# Epoch 30/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0037 - reconstruction_loss: 7.9201 - total_loss: 0.4527 - val_classification_loss: 0.0037 - val_reconstruction_loss: 7.8719 - val_total_loss: 0.4499 - learning_rate: 1.2215e-04
# Epoch 31/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0036 - reconstruction_loss: 7.8325 - total_loss: 0.4476 - val_classification_loss: 0.0037 - val_reconstruction_loss: 7.7963 - val_total_loss: 0.4456 - learning_rate: 1.2215e-04
# Epoch 32/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0036 - reconstruction_loss: 7.7653 - total_loss: 0.4438 - val_classification_loss: 0.0037 - val_reconstruction_loss: 7.7592 - val_total_loss: 0.4436 - learning_rate: 1.2215e-04
# Epoch 33/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0036 - reconstruction_loss: 7.6943 - total_loss: 0.4397 - val_classification_loss: 0.0037 - val_reconstruction_loss: 7.6936 - val_total_loss: 0.4398 - learning_rate: 1.2215e-04
# Epoch 34/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0036 - reconstruction_loss: 7.6295 - total_loss: 0.4361 - val_classification_loss: 0.0036 - val_reconstruction_loss: 7.6332 - val_total_loss: 0.4363 - learning_rate: 1.2215e-04
# Epoch 35/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0036 - reconstruction_loss: 7.5806 - total_loss: 0.4334 - val_classification_loss: 0.0037 - val_reconstruction_loss: 7.5570 - val_total_loss: 0.4321 - learning_rate: 1.2215e-04
# Epoch 36/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0035 - reconstruction_loss: 7.5230 - total_loss: 0.4300 - val_classification_loss: 0.0036 - val_reconstruction_loss: 7.4947 - val_total_loss: 0.4284 - learning_rate: 1.2215e-04
# Epoch 37/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0035 - reconstruction_loss: 7.4552 - total_loss: 0.4261 - val_classification_loss: 0.0035 - val_reconstruction_loss: 7.4474 - val_total_loss: 0.4257 - learning_rate: 1.2215e-04
# Epoch 38/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0036 - reconstruction_loss: 7.4282 - total_loss: 0.4247 - val_classification_loss: 0.0036 - val_reconstruction_loss: 7.4069 - val_total_loss: 0.4234 - learning_rate: 1.2215e-04
# Epoch 39/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0035 - reconstruction_loss: 7.3488 - total_loss: 0.4201 - val_classification_loss: 0.0034 - val_reconstruction_loss: 7.3442 - val_total_loss: 0.4197 - learning_rate: 1.2215e-04
# Epoch 40/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0035 - reconstruction_loss: 7.3136 - total_loss: 0.4181 - val_classification_loss: 0.0036 - val_reconstruction_loss: 7.3269 - val_total_loss: 0.4190 - learning_rate: 1.2215e-04
# Epoch 41/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0034 - reconstruction_loss: 7.2619 - total_loss: 0.4151 - val_classification_loss: 0.0035 - val_reconstruction_loss: 7.2540 - val_total_loss: 0.4147 - learning_rate: 1.2215e-04
# Epoch 42/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0034 - reconstruction_loss: 7.2193 - total_loss: 0.4127 - val_classification_loss: 0.0035 - val_reconstruction_loss: 7.1920 - val_total_loss: 0.4112 - learning_rate: 1.2215e-04
# Epoch 43/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0035 - reconstruction_loss: 7.1623 - total_loss: 0.4096 - val_classification_loss: 0.0035 - val_reconstruction_loss: 7.1753 - val_total_loss: 0.4102 - learning_rate: 1.2215e-04
# Epoch 44/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0034 - reconstruction_loss: 7.1264 - total_loss: 0.4074 - val_classification_loss: 0.0034 - val_reconstruction_loss: 7.1765 - val_total_loss: 0.4102 - learning_rate: 1.2215e-04
# Epoch 45/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0034 - reconstruction_loss: 7.0822 - total_loss: 0.4049 - val_classification_loss: 0.0035 - val_reconstruction_loss: 7.0923 - val_total_loss: 0.4055 - learning_rate: 1.2215e-04
# Epoch 46/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0034 - reconstruction_loss: 7.0317 - total_loss: 0.4020 - val_classification_loss: 0.0035 - val_reconstruction_loss: 7.0791 - val_total_loss: 0.4047 - learning_rate: 1.2215e-04
# Epoch 47/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0034 - reconstruction_loss: 6.9969 - total_loss: 0.4000 - val_classification_loss: 0.0034 - val_reconstruction_loss: 7.0083 - val_total_loss: 0.4007 - learning_rate: 1.2215e-04
# Epoch 48/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0034 - reconstruction_loss: 6.9452 - total_loss: 0.3971 - val_classification_loss: 0.0033 - val_reconstruction_loss: 6.9638 - val_total_loss: 0.3981 - learning_rate: 1.2215e-04
# Epoch 49/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0033 - reconstruction_loss: 6.9252 - total_loss: 0.3959 - val_classification_loss: 0.0034 - val_reconstruction_loss: 7.1284 - val_total_loss: 0.4075 - learning_rate: 1.2215e-04
# Epoch 50/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0034 - reconstruction_loss: 6.9017 - total_loss: 0.3946 - val_classification_loss: 0.0035 - val_reconstruction_loss: 6.8990 - val_total_loss: 0.3945 - learning_rate: 1.2215e-04

# %%
plot_reconstruction_analysis(
    best_suae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="best_ae_results")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 0.7120737344026562
# <ipython-input-13-198ed5571b77>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=labels, y=data, palette={'Nicht Fraud': 'blue', 'Fraud': 'red'})
# Analyse wurde gespeichert unter: /content/drive/MyDrive/best_ae_results/reconstruction_analysis_20250309_094323.png

# %%
plot_loss_curves(
    history_best_suae,
    model_type='sae',
    folder_name="best_sae_results"
)
# Out:
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/best_sae_results/loss_curves_sae.png
# (<Figure size 2000x800 with 3 Axes>,
#  array([<Axes: title={'center': 'Gesamtverlust'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'Rekonstruktionsverlust'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'Klassifikationsverlust'}, xlabel='Epoch', ylabel='Loss'>],
#        dtype=object))

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
# Evaluate the classifier on test data
_, y_pred_prob_sae = best_suae.predict(X_test)
y_pred_sae = (y_pred_prob_sae > 0.5).astype(int)  # Apply threshold at 0.5

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred_sae)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_sae, average='binary')

print(f"Classification Performance:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_prob_sae)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Supervised AE')
plt.legend(loc="lower right")
plt.show()
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# Classification Performance:
# Accuracy: 0.9993
# Precision: 0.8202
# Recall: 0.7449
# F1 Score: 0.7807

# %%
classification_report_sae = classification_report(y_test, y_pred_sae)
print(classification_report_sae)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     56864
#          1.0       0.82      0.74      0.78        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.87      0.89     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
plot_confusion_matrix(model="Supervised AE",y_true=y_test,y_pred=y_pred_sae,folder_name="sae_results")

# %%
plot_latent_space(best_suae, X_test, y_test, folder_name="best_sae_results")
# Out:
# Latenter Raum wurde gespeichert unter: /content/drive/MyDrive/best_sae_results/latent_space_SupervisedAE.png

# %% [markdown]
# ## SVAE

# %%
# Erstellen und Trainieren des Autoencoders mit anpassbaren Parametern
best_svae = SupervisedVAE(
    input_dim=X_train_normal.shape[1],
    latent_dim=data_dict['SupervisedVAE']["latent_dim"],  # Anpassbar
    activation=data_dict['SupervisedVAE']["activation"],  # Anpassbar
    dropout_rate=data_dict['SupervisedVAE']["dropout_rate"],  # Anpassbar,
    classifier_dims=[16,8],
    l2_lambda=data_dict['SupervisedVAE']["l2_lambda"]
)

best_svae.build(input_shape=(None, X_train.shape[1]))
# Konfigurieren des Optimierers
best_svae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=data_dict['SupervisedVAE']["learning_rate"]))

# Training des Autoencoders
history_best_svae = best_svae.fit(
    X_train,y_train,
    epochs=100,
    batch_size=batch_size,
    validation_split=0.1,
    verbose=1,callbacks=callbacks
)
# Out:
# Epoch 1/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - classification_loss: 0.2637 - kl_loss: 2.0964 - reconstruction_loss: 31.5465 - total_loss: 2.4169 - val_classification_loss: 0.0089 - val_kl_loss: 0.1183 - val_loss: 29.5867 - val_reconstruction_loss: 29.4596 - learning_rate: 8.8131e-04
# Epoch 2/100
#  55/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0097 - kl_loss: 0.1283 - reconstruction_loss: 30.9875 - total_loss: 0.1939
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_total_loss` which is not available. Available metrics are: classification_loss,kl_loss,reconstruction_loss,total_loss,val_classification_loss,val_kl_loss,val_loss,val_reconstruction_loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_total_loss` which is not available. Available metrics are: classification_loss,kl_loss,reconstruction_loss,total_loss,val_classification_loss,val_kl_loss,val_loss,val_reconstruction_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0080 - kl_loss: 0.1075 - reconstruction_loss: 30.3076 - total_loss: 0.1701 - val_classification_loss: 0.0058 - val_kl_loss: 0.0530 - val_loss: 29.5064 - val_reconstruction_loss: 29.4475 - learning_rate: 8.8131e-04
# Epoch 3/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0064 - kl_loss: 7.7654 - reconstruction_loss: 30.2428 - total_loss: 7.8263 - val_classification_loss: 0.0047 - val_kl_loss: 0.0377 - val_loss: 29.4838 - val_reconstruction_loss: 29.4414 - learning_rate: 8.8131e-04
# Epoch 4/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0061 - kl_loss: 0.0419 - reconstruction_loss: 30.2991 - total_loss: 0.1026 - val_classification_loss: 0.0050 - val_kl_loss: 0.0255 - val_loss: 29.4724 - val_reconstruction_loss: 29.4415 - learning_rate: 8.8131e-04
# Epoch 5/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0057 - kl_loss: 0.0274 - reconstruction_loss: 30.3008 - total_loss: 0.0877 - val_classification_loss: 0.0042 - val_kl_loss: 0.0215 - val_loss: 29.4617 - val_reconstruction_loss: 29.4361 - learning_rate: 8.8131e-04
# Epoch 6/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0049 - kl_loss: 0.0209 - reconstruction_loss: 30.2892 - total_loss: 0.0803 - val_classification_loss: 0.0046 - val_kl_loss: 0.0152 - val_loss: 29.4568 - val_reconstruction_loss: 29.4371 - learning_rate: 8.8131e-04
# Epoch 7/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0047 - kl_loss: 0.0168 - reconstruction_loss: 30.3003 - total_loss: 0.0761 - val_classification_loss: 0.0035 - val_kl_loss: 0.0125 - val_loss: 29.4545 - val_reconstruction_loss: 29.4385 - learning_rate: 8.8131e-04
# Epoch 8/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0046 - kl_loss: 0.0118 - reconstruction_loss: 30.2998 - total_loss: 0.0709 - val_classification_loss: 0.0033 - val_kl_loss: 0.0096 - val_loss: 29.4513 - val_reconstruction_loss: 29.4385 - learning_rate: 8.8131e-04
# Epoch 9/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0042 - kl_loss: 0.0090 - reconstruction_loss: 30.2990 - total_loss: 0.0678 - val_classification_loss: 0.0032 - val_kl_loss: 0.0077 - val_loss: 29.4465 - val_reconstruction_loss: 29.4356 - learning_rate: 8.8131e-04
# Epoch 10/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0039 - kl_loss: 0.0075 - reconstruction_loss: 30.2992 - total_loss: 0.0659 - val_classification_loss: 0.0036 - val_kl_loss: 0.0066 - val_loss: 29.4479 - val_reconstruction_loss: 29.4377 - learning_rate: 8.8131e-04
# Epoch 11/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0040 - kl_loss: 0.0061 - reconstruction_loss: 30.2987 - total_loss: 0.0647 - val_classification_loss: 0.0031 - val_kl_loss: 0.0052 - val_loss: 29.4444 - val_reconstruction_loss: 29.4361 - learning_rate: 8.8131e-04
# Epoch 12/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0036 - kl_loss: 0.0050 - reconstruction_loss: 30.2983 - total_loss: 0.0632 - val_classification_loss: 0.0034 - val_kl_loss: 0.0044 - val_loss: 29.4433 - val_reconstruction_loss: 29.4355 - learning_rate: 8.8131e-04
# Epoch 13/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0040 - kl_loss: 0.0042 - reconstruction_loss: 30.2974 - total_loss: 0.0627 - val_classification_loss: 0.0034 - val_kl_loss: 0.0035 - val_loss: 29.4434 - val_reconstruction_loss: 29.4364 - learning_rate: 8.8131e-04
# Epoch 14/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0038 - kl_loss: 0.0035 - reconstruction_loss: 30.2980 - total_loss: 0.0619 - val_classification_loss: 0.0028 - val_kl_loss: 0.0030 - val_loss: 29.4411 - val_reconstruction_loss: 29.4353 - learning_rate: 8.8131e-04
# Epoch 15/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0035 - kl_loss: 0.0029 - reconstruction_loss: 30.2966 - total_loss: 0.0610 - val_classification_loss: 0.0026 - val_kl_loss: 0.0026 - val_loss: 29.4376 - val_reconstruction_loss: 29.4324 - learning_rate: 8.8131e-04
# Epoch 16/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0033 - kl_loss: 0.0024 - reconstruction_loss: 30.2962 - total_loss: 0.0603 - val_classification_loss: 0.0029 - val_kl_loss: 0.0022 - val_loss: 29.4383 - val_reconstruction_loss: 29.4331 - learning_rate: 8.8131e-04
# Epoch 17/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0034 - kl_loss: 0.0021 - reconstruction_loss: 30.2960 - total_loss: 0.0600 - val_classification_loss: 0.0028 - val_kl_loss: 0.0017 - val_loss: 29.4373 - val_reconstruction_loss: 29.4327 - learning_rate: 8.8131e-04
# Epoch 18/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0036 - kl_loss: 0.0017 - reconstruction_loss: 30.2951 - total_loss: 0.0599 - val_classification_loss: 0.0028 - val_kl_loss: 0.0015 - val_loss: 29.4375 - val_reconstruction_loss: 29.4332 - learning_rate: 8.8131e-04
# Epoch 19/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0034 - kl_loss: 0.0014 - reconstruction_loss: 30.2955 - total_loss: 0.0594 - val_classification_loss: 0.0028 - val_kl_loss: 0.0013 - val_loss: 29.4353 - val_reconstruction_loss: 29.4312 - learning_rate: 8.8131e-04
# Epoch 20/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0031 - kl_loss: 0.0012 - reconstruction_loss: 30.2947 - total_loss: 0.0589 - val_classification_loss: 0.0031 - val_kl_loss: 0.0011 - val_loss: 29.4359 - val_reconstruction_loss: 29.4318 - learning_rate: 8.8131e-04
# Epoch 21/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0033 - kl_loss: 0.0011 - reconstruction_loss: 30.2947 - total_loss: 0.0590 - val_classification_loss: 0.0034 - val_kl_loss: 8.7519e-04 - val_loss: 29.4369 - val_reconstruction_loss: 29.4327 - learning_rate: 8.8131e-04
# Epoch 22/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0034 - kl_loss: 0.0010 - reconstruction_loss: 30.2945 - total_loss: 0.0590 - val_classification_loss: 0.0026 - val_kl_loss: 9.0356e-04 - val_loss: 29.4355 - val_reconstruction_loss: 29.4320 - learning_rate: 8.8131e-04
# Epoch 23/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0032 - kl_loss: 8.7227e-04 - reconstruction_loss: 30.2949 - total_loss: 0.0586 - val_classification_loss: 0.0030 - val_kl_loss: 8.0570e-04 - val_loss: 29.4362 - val_reconstruction_loss: 29.4324 - learning_rate: 8.8131e-04
# Epoch 24/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0032 - kl_loss: 7.6301e-04 - reconstruction_loss: 30.2947 - total_loss: 0.0585 - val_classification_loss: 0.0026 - val_kl_loss: 7.3501e-04 - val_loss: 29.4337 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 25/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0028 - kl_loss: 6.8116e-04 - reconstruction_loss: 30.2944 - total_loss: 0.0581 - val_classification_loss: 0.0025 - val_kl_loss: 6.7603e-04 - val_loss: 29.4352 - val_reconstruction_loss: 29.4321 - learning_rate: 8.8131e-04
# Epoch 26/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0029 - kl_loss: 6.4322e-04 - reconstruction_loss: 30.2943 - total_loss: 0.0581 - val_classification_loss: 0.0026 - val_kl_loss: 5.8833e-04 - val_loss: 29.4349 - val_reconstruction_loss: 29.4317 - learning_rate: 8.8131e-04
# Epoch 27/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0029 - kl_loss: 5.2890e-04 - reconstruction_loss: 30.2945 - total_loss: 0.0580 - val_classification_loss: 0.0026 - val_kl_loss: 5.8226e-04 - val_loss: 29.4342 - val_reconstruction_loss: 29.4310 - learning_rate: 8.8131e-04
# Epoch 28/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0029 - kl_loss: 4.9358e-04 - reconstruction_loss: 30.2943 - total_loss: 0.0579 - val_classification_loss: 0.0028 - val_kl_loss: 6.5624e-04 - val_loss: 29.4331 - val_reconstruction_loss: 29.4297 - learning_rate: 8.8131e-04
# Epoch 29/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0030 - kl_loss: 4.8269e-04 - reconstruction_loss: 30.2941 - total_loss: 0.0581 - val_classification_loss: 0.0029 - val_kl_loss: 5.1996e-04 - val_loss: 29.4337 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 30/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0029 - kl_loss: 4.1473e-04 - reconstruction_loss: 30.2940 - total_loss: 0.0579 - val_classification_loss: 0.0029 - val_kl_loss: 4.4026e-04 - val_loss: 29.4345 - val_reconstruction_loss: 29.4312 - learning_rate: 8.8131e-04
# Epoch 31/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0026 - kl_loss: 4.1078e-04 - reconstruction_loss: 30.2941 - total_loss: 0.0576 - val_classification_loss: 0.0027 - val_kl_loss: 5.6013e-04 - val_loss: 29.4334 - val_reconstruction_loss: 29.4302 - learning_rate: 8.8131e-04
# Epoch 32/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0028 - kl_loss: 3.9669e-04 - reconstruction_loss: 30.2939 - total_loss: 0.0578 - val_classification_loss: 0.0031 - val_kl_loss: 4.9446e-04 - val_loss: 29.4344 - val_reconstruction_loss: 29.4308 - learning_rate: 8.8131e-04
# Epoch 33/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0025 - kl_loss: 3.7053e-04 - reconstruction_loss: 30.2938 - total_loss: 0.0575 - val_classification_loss: 0.0029 - val_kl_loss: 4.7971e-04 - val_loss: 29.4343 - val_reconstruction_loss: 29.4309 - learning_rate: 8.8131e-04
# Epoch 34/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0025 - kl_loss: 3.5864e-04 - reconstruction_loss: 30.2939 - total_loss: 0.0574 - val_classification_loss: 0.0026 - val_kl_loss: 4.8483e-04 - val_loss: 29.4332 - val_reconstruction_loss: 29.4302 - learning_rate: 8.8131e-04
# Epoch 35/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0025 - kl_loss: 3.4809e-04 - reconstruction_loss: 30.2938 - total_loss: 0.0574 - val_classification_loss: 0.0026 - val_kl_loss: 5.0249e-04 - val_loss: 29.4337 - val_reconstruction_loss: 29.4307 - learning_rate: 8.8131e-04
# Epoch 36/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0026 - kl_loss: 3.4020e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0575 - val_classification_loss: 0.0027 - val_kl_loss: 4.7954e-04 - val_loss: 29.4344 - val_reconstruction_loss: 29.4312 - learning_rate: 8.8131e-04
# Epoch 37/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0024 - kl_loss: 3.4114e-04 - reconstruction_loss: 30.2937 - total_loss: 0.0573 - val_classification_loss: 0.0025 - val_kl_loss: 4.7296e-04 - val_loss: 29.4334 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 38/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0023 - kl_loss: 3.3328e-04 - reconstruction_loss: 30.2937 - total_loss: 0.0572 - val_classification_loss: 0.0028 - val_kl_loss: 4.0270e-04 - val_loss: 29.4340 - val_reconstruction_loss: 29.4309 - learning_rate: 8.8131e-04
# Epoch 39/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0023 - kl_loss: 3.2100e-04 - reconstruction_loss: 30.2937 - total_loss: 0.0572 - val_classification_loss: 0.0024 - val_kl_loss: 4.0367e-04 - val_loss: 29.4332 - val_reconstruction_loss: 29.4303 - learning_rate: 8.8131e-04
# Epoch 40/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0023 - kl_loss: 3.2456e-04 - reconstruction_loss: 30.2934 - total_loss: 0.0572 - val_classification_loss: 0.0022 - val_kl_loss: 5.4788e-04 - val_loss: 29.4340 - val_reconstruction_loss: 29.4312 - learning_rate: 8.8131e-04
# Epoch 41/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0023 - kl_loss: 3.2301e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0572 - val_classification_loss: 0.0030 - val_kl_loss: 5.7814e-04 - val_loss: 29.4332 - val_reconstruction_loss: 29.4297 - learning_rate: 8.8131e-04
# Epoch 42/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0023 - kl_loss: 3.2038e-04 - reconstruction_loss: 30.2934 - total_loss: 0.0572 - val_classification_loss: 0.0029 - val_kl_loss: 4.9775e-04 - val_loss: 29.4337 - val_reconstruction_loss: 29.4303 - learning_rate: 8.8131e-04
# Epoch 43/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0020 - kl_loss: 2.7806e-04 - reconstruction_loss: 30.2934 - total_loss: 0.0569 - val_classification_loss: 0.0026 - val_kl_loss: 5.4257e-04 - val_loss: 29.4337 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 44/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0023 - kl_loss: 3.0219e-04 - reconstruction_loss: 30.2934 - total_loss: 0.0571 - val_classification_loss: 0.0027 - val_kl_loss: 5.1668e-04 - val_loss: 29.4337 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 45/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0023 - kl_loss: 2.9070e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0571 - val_classification_loss: 0.0032 - val_kl_loss: 4.2694e-04 - val_loss: 29.4340 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 46/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0021 - kl_loss: 2.8047e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0569 - val_classification_loss: 0.0026 - val_kl_loss: 4.0157e-04 - val_loss: 29.4331 - val_reconstruction_loss: 29.4302 - learning_rate: 8.8131e-04
# Epoch 47/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0021 - kl_loss: 2.7740e-04 - reconstruction_loss: 30.2935 - total_loss: 0.0569 - val_classification_loss: 0.0024 - val_kl_loss: 4.2360e-04 - val_loss: 29.4333 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 48/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0019 - kl_loss: 2.6884e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0568 - val_classification_loss: 0.0027 - val_kl_loss: 4.6775e-04 - val_loss: 29.4333 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 49/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0020 - kl_loss: 2.9720e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0569 - val_classification_loss: 0.0032 - val_kl_loss: 6.3887e-04 - val_loss: 29.4342 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 50/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0019 - kl_loss: 3.0142e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0568 - val_classification_loss: 0.0033 - val_kl_loss: 5.6008e-04 - val_loss: 29.4339 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 51/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0020 - kl_loss: 2.9907e-04 - reconstruction_loss: 30.2931 - total_loss: 0.0568 - val_classification_loss: 0.0038 - val_kl_loss: 6.1310e-04 - val_loss: 29.4349 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 52/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0019 - kl_loss: 2.9607e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0567 - val_classification_loss: 0.0028 - val_kl_loss: 4.7042e-04 - val_loss: 29.4335 - val_reconstruction_loss: 29.4303 - learning_rate: 8.8131e-04
# Epoch 53/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0018 - kl_loss: 2.8647e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0567 - val_classification_loss: 0.0027 - val_kl_loss: 4.1676e-04 - val_loss: 29.4334 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 54/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0019 - kl_loss: 2.7688e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0568 - val_classification_loss: 0.0028 - val_kl_loss: 3.8697e-04 - val_loss: 29.4338 - val_reconstruction_loss: 29.4307 - learning_rate: 8.8131e-04
# Epoch 55/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0018 - kl_loss: 2.9972e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0567 - val_classification_loss: 0.0028 - val_kl_loss: 4.3294e-04 - val_loss: 29.4336 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 56/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0019 - kl_loss: 2.9899e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0568 - val_classification_loss: 0.0040 - val_kl_loss: 6.1024e-04 - val_loss: 29.4351 - val_reconstruction_loss: 29.4306 - learning_rate: 8.8131e-04
# Epoch 57/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0018 - kl_loss: 2.8638e-04 - reconstruction_loss: 30.2934 - total_loss: 0.0566 - val_classification_loss: 0.0030 - val_kl_loss: 5.3213e-04 - val_loss: 29.4339 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 58/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0017 - kl_loss: 2.7124e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0565 - val_classification_loss: 0.0037 - val_kl_loss: 5.5060e-04 - val_loss: 29.4350 - val_reconstruction_loss: 29.4308 - learning_rate: 8.8131e-04
# Epoch 59/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0020 - kl_loss: 3.2289e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0569 - val_classification_loss: 0.0029 - val_kl_loss: 4.4856e-04 - val_loss: 29.4341 - val_reconstruction_loss: 29.4307 - learning_rate: 8.8131e-04
# Epoch 60/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0017 - kl_loss: 2.9809e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0566 - val_classification_loss: 0.0032 - val_kl_loss: 4.8020e-04 - val_loss: 29.4343 - val_reconstruction_loss: 29.4306 - learning_rate: 8.8131e-04
# Epoch 61/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0016 - kl_loss: 2.9081e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0564 - val_classification_loss: 0.0027 - val_kl_loss: 5.0457e-04 - val_loss: 29.4335 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 62/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0018 - kl_loss: 2.9359e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0567 - val_classification_loss: 0.0033 - val_kl_loss: 5.4062e-04 - val_loss: 29.4339 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 63/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0017 - kl_loss: 2.9115e-04 - reconstruction_loss: 30.2935 - total_loss: 0.0565 - val_classification_loss: 0.0037 - val_kl_loss: 6.6661e-04 - val_loss: 29.4345 - val_reconstruction_loss: 29.4302 - learning_rate: 8.8131e-04
# Epoch 64/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0016 - kl_loss: 2.8765e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0565 - val_classification_loss: 0.0032 - val_kl_loss: 5.0209e-04 - val_loss: 29.4345 - val_reconstruction_loss: 29.4309 - learning_rate: 8.8131e-04
# Epoch 65/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0016 - kl_loss: 2.9681e-04 - reconstruction_loss: 30.2936 - total_loss: 0.0564 - val_classification_loss: 0.0034 - val_kl_loss: 6.0791e-04 - val_loss: 29.4339 - val_reconstruction_loss: 29.4299 - learning_rate: 8.8131e-04
# Epoch 66/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0016 - kl_loss: 2.9588e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0564 - val_classification_loss: 0.0025 - val_kl_loss: 5.3856e-04 - val_loss: 29.4332 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 67/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0017 - kl_loss: 3.2046e-04 - reconstruction_loss: 30.2931 - total_loss: 0.0566 - val_classification_loss: 0.0032 - val_kl_loss: 3.6838e-04 - val_loss: 29.4341 - val_reconstruction_loss: 29.4306 - learning_rate: 8.8131e-04
# Epoch 68/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0015 - kl_loss: 2.6775e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0563 - val_classification_loss: 0.0034 - val_kl_loss: 5.8446e-04 - val_loss: 29.4338 - val_reconstruction_loss: 29.4299 - learning_rate: 8.8131e-04
# Epoch 69/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0017 - kl_loss: 2.8612e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0565 - val_classification_loss: 0.0037 - val_kl_loss: 5.3301e-04 - val_loss: 29.4347 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 70/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0014 - kl_loss: 3.0597e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0563 - val_classification_loss: 0.0034 - val_kl_loss: 6.8868e-04 - val_loss: 29.4346 - val_reconstruction_loss: 29.4306 - learning_rate: 8.8131e-04
# Epoch 71/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0014 - kl_loss: 2.9641e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0563 - val_classification_loss: 0.0037 - val_kl_loss: 6.5500e-04 - val_loss: 29.4349 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 72/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0016 - kl_loss: 2.9439e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0565 - val_classification_loss: 0.0034 - val_kl_loss: 7.1709e-04 - val_loss: 29.4344 - val_reconstruction_loss: 29.4303 - learning_rate: 8.8131e-04
# Epoch 73/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0015 - kl_loss: 2.8168e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0564 - val_classification_loss: 0.0030 - val_kl_loss: 3.4796e-04 - val_loss: 29.4336 - val_reconstruction_loss: 29.4303 - learning_rate: 8.8131e-04
# Epoch 74/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0014 - kl_loss: 2.7133e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0562 - val_classification_loss: 0.0028 - val_kl_loss: 4.2057e-04 - val_loss: 29.4337 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 75/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0012 - kl_loss: 2.6806e-04 - reconstruction_loss: 30.2931 - total_loss: 0.0560 - val_classification_loss: 0.0033 - val_kl_loss: 8.0406e-04 - val_loss: 29.4347 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 76/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0013 - kl_loss: 2.8688e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0561 - val_classification_loss: 0.0036 - val_kl_loss: 5.4971e-04 - val_loss: 29.4342 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 77/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0016 - kl_loss: 2.8938e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0564 - val_classification_loss: 0.0027 - val_kl_loss: 5.2743e-04 - val_loss: 29.4336 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 78/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0013 - kl_loss: 2.9870e-04 - reconstruction_loss: 30.2934 - total_loss: 0.0562 - val_classification_loss: 0.0031 - val_kl_loss: 5.5451e-04 - val_loss: 29.4340 - val_reconstruction_loss: 29.4304 - learning_rate: 8.8131e-04
# Epoch 79/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0013 - kl_loss: 2.8350e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0562 - val_classification_loss: 0.0033 - val_kl_loss: 4.5113e-04 - val_loss: 29.4344 - val_reconstruction_loss: 29.4307 - learning_rate: 8.8131e-04
# Epoch 80/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0012 - kl_loss: 2.7222e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0561 - val_classification_loss: 0.0033 - val_kl_loss: 5.9414e-04 - val_loss: 29.4339 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 81/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0013 - kl_loss: 2.7457e-04 - reconstruction_loss: 30.2931 - total_loss: 0.0562 - val_classification_loss: 0.0033 - val_kl_loss: 4.7589e-04 - val_loss: 29.4340 - val_reconstruction_loss: 29.4302 - learning_rate: 8.8131e-04
# Epoch 82/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0013 - kl_loss: 3.0278e-04 - reconstruction_loss: 30.2931 - total_loss: 0.0561 - val_classification_loss: 0.0035 - val_kl_loss: 5.2962e-04 - val_loss: 29.4343 - val_reconstruction_loss: 29.4303 - learning_rate: 8.8131e-04
# Epoch 83/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0014 - kl_loss: 3.0542e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0563 - val_classification_loss: 0.0027 - val_kl_loss: 4.4511e-04 - val_loss: 29.4334 - val_reconstruction_loss: 29.4302 - learning_rate: 8.8131e-04
# Epoch 84/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0013 - kl_loss: 2.8066e-04 - reconstruction_loss: 30.2931 - total_loss: 0.0562 - val_classification_loss: 0.0034 - val_kl_loss: 3.0757e-04 - val_loss: 29.4338 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 85/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0013 - kl_loss: 2.6874e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0561 - val_classification_loss: 0.0042 - val_kl_loss: 5.7997e-04 - val_loss: 29.4354 - val_reconstruction_loss: 29.4307 - learning_rate: 8.8131e-04
# Epoch 86/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0013 - kl_loss: 2.7709e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0561 - val_classification_loss: 0.0027 - val_kl_loss: 3.7869e-04 - val_loss: 29.4331 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 87/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0011 - kl_loss: 2.5875e-04 - reconstruction_loss: 30.2930 - total_loss: 0.0559 - val_classification_loss: 0.0029 - val_kl_loss: 3.5500e-04 - val_loss: 29.4333 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 88/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - classification_loss: 0.0011 - kl_loss: 2.5518e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0559 - val_classification_loss: 0.0034 - val_kl_loss: 4.0346e-04 - val_loss: 29.4335 - val_reconstruction_loss: 29.4297 - learning_rate: 8.8131e-04
# Epoch 89/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0012 - kl_loss: 2.9358e-04 - reconstruction_loss: 30.2934 - total_loss: 0.0561 - val_classification_loss: 0.0025 - val_kl_loss: 4.8486e-04 - val_loss: 29.4330 - val_reconstruction_loss: 29.4301 - learning_rate: 8.8131e-04
# Epoch 90/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0010 - kl_loss: 2.6190e-04 - reconstruction_loss: 30.2934 - total_loss: 0.0559 - val_classification_loss: 0.0024 - val_kl_loss: 3.0244e-04 - val_loss: 29.4326 - val_reconstruction_loss: 29.4299 - learning_rate: 8.8131e-04
# Epoch 91/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 9.3998e-04 - kl_loss: 2.4753e-04 - reconstruction_loss: 30.2930 - total_loss: 0.0558 - val_classification_loss: 0.0033 - val_kl_loss: 4.7746e-04 - val_loss: 29.4340 - val_reconstruction_loss: 29.4303 - learning_rate: 8.8131e-04
# Epoch 92/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0011 - kl_loss: 2.7214e-04 - reconstruction_loss: 30.2934 - total_loss: 0.0559 - val_classification_loss: 0.0031 - val_kl_loss: 4.5624e-04 - val_loss: 29.4341 - val_reconstruction_loss: 29.4306 - learning_rate: 8.8131e-04
# Epoch 93/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0012 - kl_loss: 2.6253e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0560 - val_classification_loss: 0.0025 - val_kl_loss: 2.9877e-04 - val_loss: 29.4330 - val_reconstruction_loss: 29.4303 - learning_rate: 8.8131e-04
# Epoch 94/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 8.1497e-04 - kl_loss: 2.5551e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0556 - val_classification_loss: 0.0032 - val_kl_loss: 5.8744e-04 - val_loss: 29.4341 - val_reconstruction_loss: 29.4303 - learning_rate: 8.8131e-04
# Epoch 95/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 9.0245e-04 - kl_loss: 2.4965e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0557 - val_classification_loss: 0.0039 - val_kl_loss: 5.5327e-04 - val_loss: 29.4346 - val_reconstruction_loss: 29.4302 - learning_rate: 8.8131e-04
# Epoch 96/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 8.9870e-04 - kl_loss: 2.3706e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0557 - val_classification_loss: 0.0034 - val_kl_loss: 5.7603e-04 - val_loss: 29.4337 - val_reconstruction_loss: 29.4298 - learning_rate: 8.8131e-04
# Epoch 97/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 9.7730e-04 - kl_loss: 2.7978e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0558 - val_classification_loss: 0.0031 - val_kl_loss: 5.3167e-04 - val_loss: 29.4344 - val_reconstruction_loss: 29.4308 - learning_rate: 8.8131e-04
# Epoch 98/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0011 - kl_loss: 2.5688e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0559 - val_classification_loss: 0.0026 - val_kl_loss: 3.9681e-04 - val_loss: 29.4335 - val_reconstruction_loss: 29.4305 - learning_rate: 8.8131e-04
# Epoch 99/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 0.0012 - kl_loss: 2.6230e-04 - reconstruction_loss: 30.2933 - total_loss: 0.0560 - val_classification_loss: 0.0032 - val_kl_loss: 3.5788e-04 - val_loss: 29.4334 - val_reconstruction_loss: 29.4299 - learning_rate: 8.8131e-04
# Epoch 100/100
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - classification_loss: 8.6036e-04 - kl_loss: 2.3820e-04 - reconstruction_loss: 30.2932 - total_loss: 0.0557 - val_classification_loss: 0.0032 - val_kl_loss: 4.2344e-04 - val_loss: 29.4335 - val_reconstruction_loss: 29.4299 - learning_rate: 8.8131e-04

# %%
plot_reconstruction_analysis(
    best_svae,
    X_test,
    y_test,  # Labels für Testdaten (0 für Nicht Fraud, 1 für Fraud)
    folder_name="best_svae_results")
# Out:
# Optimaler Schwellenwert (quantile 0.95): 1.9636224925518035
# <ipython-input-13-198ed5571b77>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=labels, y=data, palette={'Nicht Fraud': 'blue', 'Fraud': 'red'})
# Analyse wurde gespeichert unter: /content/drive/MyDrive/best_svae_results/reconstruction_analysis_20250309_101856.png

# %%
plot_loss_curves(
    history_best_svae,
    model_type='svae',
    folder_name="best_svae_results"
)
# Out:
# Loss-Kurven wurden gespeichert unter: /content/drive/MyDrive/best_svae_results/loss_curves_svae.png
# (<Figure size 2000x800 with 4 Axes>,
#  array([<Axes: title={'center': 'Gesamtverlust'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'Rekonstruktionsverlust'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'KL-Divergenz'}, xlabel='Epoch', ylabel='Loss'>,
#         <Axes: title={'center': 'Klassifikationsverlust'}, xlabel='Epoch', ylabel='Loss'>],
#        dtype=object))

# %%
# Evaluate the classifier on test data
_,_,_, y_pred_prob_svae = best_svae.predict(X_test)
y_pred_svae = (y_pred_prob_svae > 0.5).astype(int)  # Apply threshold at 0.5

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred_svae)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_svae, average='binary')

print(f"Classification Performance:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_prob_svae)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step
# Classification Performance:
# Accuracy: 0.9995
# Precision: 0.8778
# Recall: 0.8061
# F1 Score: 0.8404

# %%
classification_report_svae = classification_report(y_test, y_pred_svae)
print(classification_report_svae)
plot_confusion_matrix(model="Supervised VAE",y_true=y_test,y_pred=y_pred_svae,folder_name="best_sae_results")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     56864
#          1.0       0.88      0.81      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.90      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
plot_latent_space(
    best_svae,
    X_test,
    np.squeeze(y_test),  # Squeeze y_test, um (n_samples,) zu erhalten
    folder_name="best_svae_results/latent_space"
)
# Out:
# Latenter Raum wurde gespeichert unter: /content/drive/MyDrive/best_svae_results/latent_space/latent_space_SupervisedVAE.png
